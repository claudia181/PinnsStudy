# %%
from plot_utils import plot_points, plot_model_stats, print_model_info, plot_loss
import os
from evaluate import evaluate

# %% [markdown]
# # Data

# %%
plot_points('data/train/0/full/random_dom.pth', points_idx = 0, labels_idx = 1)

# %% [markdown]
# # PINN 0

# %%
path = "models/AllenCahnSingle0/Outfull0ti"

subdirs = []
for entry_name in os.listdir(path):
        full_path = os.path.join(path, entry_name)
        if os.path.isdir(full_path):
                subdirs.append(entry_name)

selection = [
        "trial0",
        "trial1",
        "trial2",
        "trial3",
        "trial4",
        "trial5",
        "trial6",
        "trial7",
        "trial8",
        "trial9",
        "trial10",
        "trial11",
        "trial12",
        "trial13",
        "trial14",
        "trial15",
        "trial16",
        "trial17",
        "trial18",
        "trial19",
        "trial20",
        "best_trial"
        ]

labels = [trial for trial in os.listdir(path) if trial in selection]
filepaths=[os.path.join(path, trial) + "/train_stats.npy" for trial in subdirs if trial in selection]

plot_model_stats(filepaths=filepaths, labels=labels, to_plot=["train"])

filepaths=[os.path.join(path, trial) + "/test_stats.npy" for trial in subdirs if trial in selection]

plot_model_stats(filepaths=filepaths, labels=labels, to_plot=["test"])

# %%
best_trial = "best_trial"
labels = [best_trial, best_trial]
filepaths=[os.path.join(path, best_trial) + "/train_stats.npy", os.path.join(path, best_trial) + "/test_stats.npy"]
plot_model_stats(filepaths=filepaths, labels=labels, to_plot=["train", "test"])
print_model_info(filepath=os.path.join(path, best_trial) + "/model.pth")
# Out:
# Last train loss: 0.07094891369342804
# Last test loss: 0.07733936607837677
# --- Model Parameters ---
# PDE Name: Allen-Cahn
# PDE Parameters: [0.01]
# Hidden Units: [50, 50, 50, 50]
# Initial Learning Rate (lr_init): 0.0007340357692788194
# Batch size (batch_size): 2048
# BC Loss Weight: 1.0
# IC Loss Weight: 1.0
# Physics Loss Weight: 1.0
# Distillation Loss Weight: 1.0
# EWC Loss Weight: 1.0
# Activation Function: Tanh()

# %%
best_trial = "best_trial"
labels = [best_trial, best_trial]
filepaths=[os.path.join(path, best_trial) + "/train_stats.npy", os.path.join(path, best_trial) + "/test_stats.npy"]
plot_model_stats(filepaths=filepaths, labels=labels, to_plot=["pde"])
print_model_info(filepath=os.path.join(path, best_trial) + "/model.pth")
# Out:
# Last pde: 0.036433104425668716
# Last pde: 0.03719742223620415
# --- Model Parameters ---
# PDE Name: Allen-Cahn
# PDE Parameters: [0.01]
# Hidden Units: [50, 50, 50, 50]
# Initial Learning Rate (lr_init): 0.0007340357692788194
# Batch size (batch_size): 2048
# BC Loss Weight: 1.0
# IC Loss Weight: 1.0
# Physics Loss Weight: 1.0
# Distillation Loss Weight: 1.0
# EWC Loss Weight: 1.0
# Activation Function: Tanh()

# %%
best_trial = "best_trial"
labels = [best_trial, best_trial]
filepaths=[os.path.join(path, best_trial) + "/train_stats.npy", os.path.join(path, best_trial) + "/test_stats.npy"]
plot_model_stats(filepaths=filepaths, labels=labels, to_plot=["bc"])
print_model_info(filepath=os.path.join(path, best_trial) + "/model.pth")
# Out:
# Last bc: 0.0
# Last bc: 0.0
# --- Model Parameters ---
# PDE Name: Allen-Cahn
# PDE Parameters: [0.01]
# Hidden Units: [50, 50, 50, 50]
# Initial Learning Rate (lr_init): 0.0007340357692788194
# Batch size (batch_size): 2048
# BC Loss Weight: 1.0
# IC Loss Weight: 1.0
# Physics Loss Weight: 1.0
# Distillation Loss Weight: 1.0
# EWC Loss Weight: 1.0
# Activation Function: Tanh()

# %%
best_trial = "best_trial"
labels = [best_trial, best_trial]
filepaths=[os.path.join(path, best_trial) + "/train_stats.npy", os.path.join(path, best_trial) + "/test_stats.npy"]
plot_model_stats(filepaths=filepaths, labels=labels, to_plot=["der"])
print_model_info(filepath=os.path.join(path, best_trial) + "/model.pth")
# Out:
# Last der: 1.7553372383117676
# Last der: 1.813875675201416
# --- Model Parameters ---
# PDE Name: Allen-Cahn
# PDE Parameters: [0.01]
# Hidden Units: [50, 50, 50, 50]
# Initial Learning Rate (lr_init): 0.0007340357692788194
# Batch size (batch_size): 2048
# BC Loss Weight: 1.0
# IC Loss Weight: 1.0
# Physics Loss Weight: 1.0
# Distillation Loss Weight: 1.0
# EWC Loss Weight: 1.0
# Activation Function: Tanh()

# %%
best_trial = "best_trial"
labels = [best_trial, best_trial]
filepaths=[os.path.join(path, best_trial) + "/train_stats.npy", os.path.join(path, best_trial) + "/test_stats.npy"]
plot_model_stats(filepaths=filepaths, labels=labels, to_plot=["hes"])
print_model_info(filepath=os.path.join(path, best_trial) + "/model.pth")
# Out:
# Last hes: 10.401565551757812
# Last hes: 11.109456062316895
# --- Model Parameters ---
# PDE Name: Allen-Cahn
# PDE Parameters: [0.01]
# Hidden Units: [50, 50, 50, 50]
# Initial Learning Rate (lr_init): 0.0007340357692788194
# Batch size (batch_size): 2048
# BC Loss Weight: 1.0
# IC Loss Weight: 1.0
# Physics Loss Weight: 1.0
# Distillation Loss Weight: 1.0
# EWC Loss Weight: 1.0
# Activation Function: Tanh()

# %%
best_trial = "best_trial"
labels = [best_trial, best_trial]
filepaths=[
    os.path.join(path, best_trial) + "/train_stats.npy",
    #os.path.join(path, best_trial) + "/test_stats.npy"
    ]
plot_model_stats(filepaths=filepaths, labels=labels, to_plot=["out"])
print_model_info(filepath=os.path.join(path, best_trial) + "/model.pth")
# Out:
# Last out: 0.07094891369342804
# --- Model Parameters ---
# PDE Name: Allen-Cahn
# PDE Parameters: [0.01]
# Hidden Units: [50, 50, 50, 50]
# Initial Learning Rate (lr_init): 0.0007340357692788194
# Batch size (batch_size): 2048
# BC Loss Weight: 1.0
# IC Loss Weight: 1.0
# Physics Loss Weight: 1.0
# Distillation Loss Weight: 1.0
# EWC Loss Weight: 1.0
# Activation Function: Tanh()

# %% [markdown]
# # PINN 1

# %%
path = "models/forgetting/AllenCahnSingle5/PINNfull1ti"

subdirs = []
for entry_name in os.listdir(path):
        full_path = os.path.join(path, entry_name)
        if os.path.isdir(full_path):
                subdirs.append(entry_name)

selection = [
        "trial0",
        "trial1",
        "trial2",
        "trial3",
        "trial4",
        "trial5",
        "trial6",
        "trial7",
        "trial8",
        "trial9",
        "best_trial"
        ]

labels = [trial for trial in os.listdir(path) if trial in selection]
filepaths=[os.path.join(path, trial) + "/train_stats.npy" for trial in subdirs if trial in selection]

plot_model_stats(filepaths=filepaths, labels=labels, to_plot=["train"])

filepaths=[os.path.join(path, trial) + "/test_stats.npy" for trial in subdirs if trial in selection]

plot_model_stats(filepaths=filepaths, labels=labels, to_plot=["test"])

# %%
best_trial = "trial2"
labels = [best_trial, best_trial]
filepaths=[os.path.join(path, best_trial) + "/train_stats.npy", os.path.join(path, best_trial) + "/test_stats.npy"]
plot_model_stats(filepaths=filepaths, labels=labels, to_plot=["out"])
print_model_info(filepath=os.path.join(path, best_trial) + "/model.pth")
# Out:
# Last out: 1.105690598487854
# Last out: 1.080305576324463
# --- Model Parameters ---
# PDE Name: Allen-Cahn
# PDE Parameters: [5.0]
# Hidden Units: [50, 50, 50, 50]
# Initial Learning Rate (lr_init): 5.673322688154075e-05
# Batch size (batch_size): 2048
# BC Loss Weight: 0.0011355775361486515
# IC Loss Weight: 1.0
# Physics Loss Weight: 0.0017543382195963045
# Distillation Loss Weight: 1.0
# EWC Loss Weight: 1.0
# Activation Function: Tanh()

# %% [markdown]
# # PINN 2

# %%
path = "models/AllenCahnSingle10/PINNfull2"

subdirs = []
for entry_name in os.listdir(path):
        full_path = os.path.join(path, entry_name)
        if os.path.isdir(full_path):
                subdirs.append(entry_name)

selection = [
        "trial0",
        "trial1",
        "trial2",
        "trial3",
        "trial4",
        "trial5",
        "trial6",
        "trial7",
        "trial8",
        "trial9"
        ]

labels = [trial for trial in os.listdir(path) if trial in selection]
filepaths=[os.path.join(path, trial) + "/train_stats.npy" for trial in subdirs if trial in selection]

plot_model_stats(filepaths=filepaths, labels=labels, to_plot=["train"])

filepaths=[os.path.join(path, trial) + "/test_stats.npy" for trial in subdirs if trial in selection]

plot_model_stats(filepaths=filepaths, labels=labels, to_plot=["test"])

# %%
best_trial = "trial0"
labels = [best_trial, best_trial]
filepaths=[os.path.join(path, best_trial) + "/train_stats.npy", os.path.join(path, best_trial) + "/test_stats.npy"]
plot_model_stats(filepaths=filepaths, labels=labels, to_plot=["train", "test"])
print_model_info(filepath=os.path.join(path, best_trial) + "/model.pth")
# Out:
# --- Model Parameters ---
# PDE Name: Allen-Cahn
# PDE Parameters: [1.0]
# Hidden Units: [50, 50, 50, 50]
# Initial Learning Rate (lr_init): 7.508569727532212e-05
# Batch size (batch_size): 2048
# BC Loss Weight: 0.07023155682572046
# IC Loss Weight: 1.0
# Physics Loss Weight: 0.001822706204678068
# Distillation Loss Weight: 1.0
# EWC Loss Weight: 1.0
# Activation Function: Tanh()

# %%
best_trials0.append(best_trial)

# %% [markdown]
# # PINN 3

# %%
path = "models/AllenCahnSingle15/PINNfull3"

subdirs = []
for entry_name in os.listdir(path):
        full_path = os.path.join(path, entry_name)
        if os.path.isdir(full_path):
                subdirs.append(entry_name)

selection = [
        "trial0",
        "trial1",
        "trial2",
        "trial3",
        "trial4",
        "trial5",
        "trial6",
        "trial7",
        "trial8",
        "trial9"
        ]

labels = [trial for trial in os.listdir(path) if trial in selection]
filepaths=[os.path.join(path, trial) + "/train_stats.npy" for trial in subdirs if trial in selection]

plot_model_stats(filepaths=filepaths, labels=labels, to_plot=["train"])

filepaths=[os.path.join(path, trial) + "/test_stats.npy" for trial in subdirs if trial in selection]

plot_model_stats(filepaths=filepaths, labels=labels, to_plot=["test"])

# %%
best_trial = "trial0"
labels = [best_trial, best_trial]
filepaths=[os.path.join(path, best_trial) + "/train_stats.npy", os.path.join(path, best_trial) + "/test_stats.npy"]
plot_model_stats(filepaths=filepaths, labels=labels, to_plot=["train", "test"])
print_model_info(filepath=os.path.join(path, best_trial) + "/model.pth")
# Out:
# --- Model Parameters ---
# PDE Name: Allen-Cahn
# PDE Parameters: [1.5]
# Hidden Units: [50, 50, 50, 50]
# Initial Learning Rate (lr_init): 7.508569727532212e-05
# Batch size (batch_size): 2048
# BC Loss Weight: 0.07023155682572046
# IC Loss Weight: 1.0
# Physics Loss Weight: 0.001822706204678068
# Distillation Loss Weight: 1.0
# EWC Loss Weight: 1.0
# Activation Function: Tanh()

# %%
best_trials0.append(best_trial)

# %% [markdown]
# # Eval

# %%
best_trials0
# Out:
# ['trial5', 'trial9', 'trial0', 'trial0']

# %%
mode = "forgetting"
model_prefix = f"models/"
model_suffix = "/model.pth"
data_prefix = "data/val/"
data_suffix = "/full/random_dom.pth"

# %%
model_names = ["AllenCahnSingle0/PINNfull0", f"{mode}/AllenCahnSingle5/PINNfull1", f"{mode}/AllenCahnSingle10/PINNfull2", f"{mode}/AllenCahnSingle15/PINNfull3"]
data_names = [
    "0",
    "5",
    "10",
    "15",
    "20",
    "25",
    "30",
    "35"
    ]

model_paths = [model_prefix + f"{model_name}/{trial}" + model_suffix for model_name, trial in zip(model_names, best_trials0)]
data_paths = [data_prefix + data_name + data_suffix for data_name in data_names]
plot_loss(model_sequence=model_paths, losses=["pde"], data_sequence=data_paths, title="PDE Loss Evolution Full Domain")

# %%
model_names = ["AllenCahnSingle0/PINNfull0", f"{mode}/AllenCahnSingle5/PINNfull1", f"{mode}/AllenCahnSingle10/PINNfull2", f"{mode}/AllenCahnSingle15/PINNfull3"]
data_names = [
    "0",
    #"5",
    #"10",
    #"15",
    #"20",
    #"25",
    #"30",
    #"35"
    ]

model_paths = [model_prefix + f"{model_name}/{trial}" + model_suffix for model_name, trial in zip(model_names, best_trials0)]
data_paths = [data_prefix + data_name + data_suffix for data_name in data_names]
plot_loss(model_sequence=model_paths, losses=["out"], data_sequence=data_paths, title="OUT Loss Evolution Full Domain")

# %%
model_names = ["AllenCahnSingle0/PINNfull0", f"{mode}/AllenCahnSingle5/PINNfull1", f"{mode}/AllenCahnSingle10/PINNfull2", f"{mode}/AllenCahnSingle15/PINNfull3"]
data_names = [
    "0",
    #"5",
    #"10",
    #"15",
    #"20",
    #"25",
    #"30",
    #"35"
    ]

model_paths = [model_prefix + f"{model_name}/{trial}" + model_suffix for model_name, trial in zip(model_names, best_trials0)]
data_paths = [data_prefix + data_name + data_suffix for data_name in data_names]
plot_loss(model_sequence=model_paths, losses=["der"], data_sequence=data_paths, title="DER Loss Evolution Full Domain")

# %%
model_names = ["AllenCahnSingle0/PINNfull0", f"{mode}/AllenCahnSingle5/PINNfull1", f"{mode}/AllenCahnSingle10/PINNfull2", f"{mode}/AllenCahnSingle15/PINNfull3"]
data_names = [
    "0",
    #"5",
    #"10",
    #"15",
    #"20",
    #"25",
    #"30",
    #"35"
    ]

model_paths = [model_prefix + f"{model_name}/{trial}" + model_suffix for model_name, trial in zip(model_names, best_trials0)]
data_paths = [data_prefix + data_name + data_suffix for data_name in data_names]
plot_loss(model_sequence=model_paths, losses=["hes"], data_sequence=data_paths, title="HES Loss Evolution Full Domain")

# %%
model_names = ["AllenCahnSingle0/PINNfull0", f"{mode}/AllenCahnSingle5/PINNfull1", f"{mode}/AllenCahnSingle10/PINNfull2", f"{mode}/AllenCahnSingle15/PINNfull3"]
data_names = [
    "0",
    "5",
    "10",
    "15",
    "20",
    "25",
    "30",
    "35"
    ]

model_paths = [model_prefix + f"{model_name}/{trial}" + model_suffix for model_name, trial in zip(model_names, best_trials0)]
data_paths = [data_prefix + data_name + data_suffix for data_name in data_names]

for model_name, model_path, data_path in zip(model_names, model_paths, data_paths):
    evaluate(model_path=model_path, data_path=data_path, model_name=model_name, print_info=True)
# Out:
# -------- AllenCahnSingle0/PINNfull0 --------
# OUT loss: 0.25339627265930176
# DER loss: 1.817930817604065
# HES loss: 18.323158264160156
# PDE loss: 0.04721822962164879
#
# -------- forgetting/AllenCahnSingle5/PINNfull1 --------
# OUT loss: 0.1410265862941742
# DER loss: 1.0670057535171509
# HES loss: 10.486824035644531
# PDE loss: 0.04490484297275543
#
# -------- forgetting/AllenCahnSingle10/PINNfull2 --------
# OUT loss: 0.0995703637599945
# DER loss: 0.822740912437439
# HES loss: 7.832252025604248
# PDE loss: 0.03272188454866409
#
# -------- forgetting/AllenCahnSingle15/PINNfull3 --------
# OUT loss: 0.08326469361782074
# DER loss: 0.7421125769615173
# HES loss: 7.143244743347168
# PDE loss: 0.027827341109514236
