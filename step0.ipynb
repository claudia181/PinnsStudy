# %%
from plot_utils import plot_points, plot_model_stats, print_model_info, plot_loss
import os
from evaluate import evaluate

# %%
plot_points('data/train/0/full/random_dom.pth', points_idx = 0, labels_idx = 1)

# %% [markdown]
# # OUT

# %%
path = "models/step0/AllenCahnSingle0/OUTfullAAA"

subdirs = []
for entry_name in os.listdir(path):
        full_path = os.path.join(path, entry_name)
        if os.path.isdir(full_path):
                subdirs.append(entry_name)

selection = [
        "trial0",
        "trial1",
        "trial2",
        "trial3",
        "trial4",
        "trial5",
        "trial6",
        "trial7",
        "trial8",
        "trial9",
        "trial10",
        "trial11",
        "trial12",
        "trial13",
        "trial14",
        "trial15",
        "trial16",
        "trial17",
        "trial18",
        "trial19",
        "trial20",
        "best_trial"
        ]

labels = [trial for trial in os.listdir(path) if trial in selection]
filepaths=[os.path.join(path, trial) + "/train_stats.npy" for trial in subdirs if trial in selection]

plot_model_stats(filepaths=filepaths, labels=labels, to_plot=["train"])

filepaths=[os.path.join(path, trial) + "/test_stats.npy" for trial in subdirs if trial in selection]

plot_model_stats(filepaths=filepaths, labels=labels, to_plot=["test"])

# %%
path = "models/step0/AllenCahnSingle0/OUTfullA"
best_trial = "best_trial"
labels = [best_trial, best_trial]
filepaths=[os.path.join(path, best_trial) + "/train_stats.npy", os.path.join(path, best_trial) + "/test_stats.npy"]
plot_model_stats(filepaths=filepaths, labels=labels, to_plot=["train", "test"])
print_model_info(filepath=os.path.join(path, best_trial) + "/model.pth")
print("")
path = "models/step0/AllenCahnSingle0/OUTfullAA"
best_trial = "best_trial"
labels = [best_trial, best_trial]
filepaths=[os.path.join(path, best_trial) + "/train_stats.npy", os.path.join(path, best_trial) + "/test_stats.npy"]
plot_model_stats(filepaths=filepaths, labels=labels, to_plot=["train", "test"])
print_model_info(filepath=os.path.join(path, best_trial) + "/model.pth")
print("")
path = "models/step0/AllenCahnSingle0/OUTfullAAA"
best_trial = "best_trial"
labels = [best_trial, best_trial]
filepaths=[os.path.join(path, best_trial) + "/train_stats.npy", os.path.join(path, best_trial) + "/test_stats.npy"]
plot_model_stats(filepaths=filepaths, labels=labels, to_plot=["train", "test"])
print_model_info(filepath=os.path.join(path, best_trial) + "/model.pth")
# Out:
# Last train loss: 0.02425762638449669
# Last test loss: 0.02381928637623787
# --- Model Parameters ---
# PDE Name: Allen-Cahn
# PDE Parameters: [0.0]
# Hidden Units: [50, 50, 50, 50]
# Initial Learning Rate (lr_init): 0.0008866251448974667
# Batch size (batch_size): 2048
# BC Loss Weight: 1.0
# IC Loss Weight: 1.0
# Physics Loss Weight: 1.0
# Distillation Loss Weight: 1.0
# EWC Loss Weight: 1.0
# Activation Function: Tanh()
#
# Last train loss: 0.21409742534160614
# Last test loss: 0.2109573483467102
# --- Model Parameters ---
# PDE Name: Allen-Cahn
# PDE Parameters: [0.0]
# Hidden Units: [50, 50, 50, 50]
# Initial Learning Rate (lr_init): 8.405130023482932e-05
# Batch size (batch_size): 2048
# BC Loss Weight: 1.0
# IC Loss Weight: 1.0
# Physics Loss Weight: 1.0
# Distillation Loss Weight: 1.0
# EWC Loss Weight: 1.0
# Activation Function: Tanh()
#
# Last train loss: 0.12777350842952728
# Last test loss: 0.12453275173902512
# --- Model Parameters ---
# PDE Name: Allen-Cahn
# PDE Parameters: [0.0]
# Hidden Units: [50, 50, 50, 50]
# Initial Learning Rate (lr_init): 7.199280632567906e-05
# Batch size (batch_size): 2048
# BC Loss Weight: 1.0
# IC Loss Weight: 1.0
# Physics Loss Weight: 1.0
# Distillation Loss Weight: 1.0
# EWC Loss Weight: 1.0
# Activation Function: Tanh()

# %%
path = "models/step0/AllenCahnSingle0/OUTfullA"
best_trial = "best_trial"
labels = [best_trial, best_trial]
filepaths=[os.path.join(path, best_trial) + "/train_stats.npy", os.path.join(path, best_trial) + "/test_stats.npy"]
plot_model_stats(filepaths=filepaths, labels=labels, to_plot=["pde"])
print_model_info(filepath=os.path.join(path, best_trial) + "/model.pth")
print("")
path = "models/step0/AllenCahnSingle0/OUTfullAA"
best_trial = "best_trial"
labels = [best_trial, best_trial]
filepaths=[os.path.join(path, best_trial) + "/train_stats.npy", os.path.join(path, best_trial) + "/test_stats.npy"]
plot_model_stats(filepaths=filepaths, labels=labels, to_plot=["pde"])
print_model_info(filepath=os.path.join(path, best_trial) + "/model.pth")
print("")
path = "models/step0/AllenCahnSingle0/OUTfullAAA"
best_trial = "best_trial"
labels = [best_trial, best_trial]
filepaths=[os.path.join(path, best_trial) + "/train_stats.npy", os.path.join(path, best_trial) + "/test_stats.npy"]
plot_model_stats(filepaths=filepaths, labels=labels, to_plot=["pde"])
print_model_info(filepath=os.path.join(path, best_trial) + "/model.pth")
# Out:
# Last pde: 0.0408627912402153
# Last pde: 0.0394463986158371
# --- Model Parameters ---
# PDE Name: Allen-Cahn
# PDE Parameters: [0.0]
# Hidden Units: [50, 50, 50, 50]
# Initial Learning Rate (lr_init): 0.0008866251448974667
# Batch size (batch_size): 2048
# BC Loss Weight: 1.0
# IC Loss Weight: 1.0
# Physics Loss Weight: 1.0
# Distillation Loss Weight: 1.0
# EWC Loss Weight: 1.0
# Activation Function: Tanh()
#
# Last pde: 0.0314902663230896
# Last pde: 0.032878533005714417
# --- Model Parameters ---
# PDE Name: Allen-Cahn
# PDE Parameters: [0.0]
# Hidden Units: [50, 50, 50, 50]
# Initial Learning Rate (lr_init): 8.405130023482932e-05
# Batch size (batch_size): 2048
# BC Loss Weight: 1.0
# IC Loss Weight: 1.0
# Physics Loss Weight: 1.0
# Distillation Loss Weight: 1.0
# EWC Loss Weight: 1.0
# Activation Function: Tanh()
#
# Last pde: 0.029337119311094284
# Last pde: 0.028764579445123672
# --- Model Parameters ---
# PDE Name: Allen-Cahn
# PDE Parameters: [0.0]
# Hidden Units: [50, 50, 50, 50]
# Initial Learning Rate (lr_init): 7.199280632567906e-05
# Batch size (batch_size): 2048
# BC Loss Weight: 1.0
# IC Loss Weight: 1.0
# Physics Loss Weight: 1.0
# Distillation Loss Weight: 1.0
# EWC Loss Weight: 1.0
# Activation Function: Tanh()

# %%
path = "models/step0/AllenCahnSingle0/OUTfullA"
best_trial = "best_trial"
labels = [best_trial, best_trial]
filepaths=[os.path.join(path, best_trial) + "/train_stats.npy", os.path.join(path, best_trial) + "/test_stats.npy"]
plot_model_stats(filepaths=filepaths, labels=labels, to_plot=["out"])
print_model_info(filepath=os.path.join(path, best_trial) + "/model.pth")
print("")
path = "models/step0/AllenCahnSingle0/OUTfullAA"
best_trial = "best_trial"
labels = [best_trial, best_trial]
filepaths=[os.path.join(path, best_trial) + "/train_stats.npy", os.path.join(path, best_trial) + "/test_stats.npy"]
plot_model_stats(filepaths=filepaths, labels=labels, to_plot=["out"])
print_model_info(filepath=os.path.join(path, best_trial) + "/model.pth")
print("")
path = "models/step0/AllenCahnSingle0/OUTfullAAA"
best_trial = "best_trial"
labels = [best_trial, best_trial]
filepaths=[os.path.join(path, best_trial) + "/train_stats.npy", os.path.join(path, best_trial) + "/test_stats.npy"]
plot_model_stats(filepaths=filepaths, labels=labels, to_plot=["out"])
print_model_info(filepath=os.path.join(path, best_trial) + "/model.pth")
# Out:
# Last out: 0.02425762638449669
# Last out: 0.02381928637623787
# --- Model Parameters ---
# PDE Name: Allen-Cahn
# PDE Parameters: [0.0]
# Hidden Units: [50, 50, 50, 50]
# Initial Learning Rate (lr_init): 0.0008866251448974667
# Batch size (batch_size): 2048
# BC Loss Weight: 1.0
# IC Loss Weight: 1.0
# Physics Loss Weight: 1.0
# Distillation Loss Weight: 1.0
# EWC Loss Weight: 1.0
# Activation Function: Tanh()
#
# Last out: 0.21409742534160614
# Last out: 0.2109573483467102
# --- Model Parameters ---
# PDE Name: Allen-Cahn
# PDE Parameters: [0.0]
# Hidden Units: [50, 50, 50, 50]
# Initial Learning Rate (lr_init): 8.405130023482932e-05
# Batch size (batch_size): 2048
# BC Loss Weight: 1.0
# IC Loss Weight: 1.0
# Physics Loss Weight: 1.0
# Distillation Loss Weight: 1.0
# EWC Loss Weight: 1.0
# Activation Function: Tanh()
#
# Last out: 0.12777350842952728
# Last out: 0.12453275173902512
# --- Model Parameters ---
# PDE Name: Allen-Cahn
# PDE Parameters: [0.0]
# Hidden Units: [50, 50, 50, 50]
# Initial Learning Rate (lr_init): 7.199280632567906e-05
# Batch size (batch_size): 2048
# BC Loss Weight: 1.0
# IC Loss Weight: 1.0
# Physics Loss Weight: 1.0
# Distillation Loss Weight: 1.0
# EWC Loss Weight: 1.0
# Activation Function: Tanh()

# %%
path = "models/step0/AllenCahnSingle0/OUTfullA"
best_trial = "best_trial"
labels = [best_trial, best_trial]
filepaths=[os.path.join(path, best_trial) + "/train_stats.npy", os.path.join(path, best_trial) + "/test_stats.npy"]
plot_model_stats(filepaths=filepaths, labels=labels, to_plot=["der"])
print_model_info(filepath=os.path.join(path, best_trial) + "/model.pth")
print("")
path = "models/step0/AllenCahnSingle0/OUTfullAA"
best_trial = "best_trial"
labels = [best_trial, best_trial]
filepaths=[os.path.join(path, best_trial) + "/train_stats.npy", os.path.join(path, best_trial) + "/test_stats.npy"]
plot_model_stats(filepaths=filepaths, labels=labels, to_plot=["der"])
print_model_info(filepath=os.path.join(path, best_trial) + "/model.pth")
print("")
path = "models/step0/AllenCahnSingle0/OUTfullAAA"
best_trial = "best_trial"
labels = [best_trial, best_trial]
filepaths=[os.path.join(path, best_trial) + "/train_stats.npy", os.path.join(path, best_trial) + "/test_stats.npy"]
plot_model_stats(filepaths=filepaths, labels=labels, to_plot=["der"])
print_model_info(filepath=os.path.join(path, best_trial) + "/model.pth")
# Out:
# Last der: 1.843743920326233
# Last der: 1.8175780773162842
# --- Model Parameters ---
# PDE Name: Allen-Cahn
# PDE Parameters: [0.0]
# Hidden Units: [50, 50, 50, 50]
# Initial Learning Rate (lr_init): 0.0008866251448974667
# Batch size (batch_size): 2048
# BC Loss Weight: 1.0
# IC Loss Weight: 1.0
# Physics Loss Weight: 1.0
# Distillation Loss Weight: 1.0
# EWC Loss Weight: 1.0
# Activation Function: Tanh()
#
# Last der: 1.8707879781723022
# Last der: 1.8609167337417603
# --- Model Parameters ---
# PDE Name: Allen-Cahn
# PDE Parameters: [0.0]
# Hidden Units: [50, 50, 50, 50]
# Initial Learning Rate (lr_init): 8.405130023482932e-05
# Batch size (batch_size): 2048
# BC Loss Weight: 1.0
# IC Loss Weight: 1.0
# Physics Loss Weight: 1.0
# Distillation Loss Weight: 1.0
# EWC Loss Weight: 1.0
# Activation Function: Tanh()
#
# Last der: 2.1008667945861816
# Last der: 2.0728225708007812
# --- Model Parameters ---
# PDE Name: Allen-Cahn
# PDE Parameters: [0.0]
# Hidden Units: [50, 50, 50, 50]
# Initial Learning Rate (lr_init): 7.199280632567906e-05
# Batch size (batch_size): 2048
# BC Loss Weight: 1.0
# IC Loss Weight: 1.0
# Physics Loss Weight: 1.0
# Distillation Loss Weight: 1.0
# EWC Loss Weight: 1.0
# Activation Function: Tanh()

# %%
path = "models/step0/AllenCahnSingle0/OUTfullA"
best_trial = "best_trial"
labels = [best_trial, best_trial]
filepaths=[os.path.join(path, best_trial) + "/train_stats.npy", os.path.join(path, best_trial) + "/test_stats.npy"]
plot_model_stats(filepaths=filepaths, labels=labels, to_plot=["hes"])
print_model_info(filepath=os.path.join(path, best_trial) + "/model.pth")
print("")
path = "models/step0/AllenCahnSingle0/OUTfullAA"
best_trial = "best_trial"
labels = [best_trial, best_trial]
filepaths=[os.path.join(path, best_trial) + "/train_stats.npy", os.path.join(path, best_trial) + "/test_stats.npy"]
plot_model_stats(filepaths=filepaths, labels=labels, to_plot=["hes"])
print_model_info(filepath=os.path.join(path, best_trial) + "/model.pth")
print("")
path = "models/step0/AllenCahnSingle0/OUTfullAAA"
best_trial = "best_trial"
labels = [best_trial, best_trial]
filepaths=[os.path.join(path, best_trial) + "/train_stats.npy", os.path.join(path, best_trial) + "/test_stats.npy"]
plot_model_stats(filepaths=filepaths, labels=labels, to_plot=["hes"])
print_model_info(filepath=os.path.join(path, best_trial) + "/model.pth")
# Out:
# Last hes: 17.599937438964844
# Last hes: 18.11784553527832
# --- Model Parameters ---
# PDE Name: Allen-Cahn
# PDE Parameters: [0.0]
# Hidden Units: [50, 50, 50, 50]
# Initial Learning Rate (lr_init): 0.0008866251448974667
# Batch size (batch_size): 2048
# BC Loss Weight: 1.0
# IC Loss Weight: 1.0
# Physics Loss Weight: 1.0
# Distillation Loss Weight: 1.0
# EWC Loss Weight: 1.0
# Activation Function: Tanh()
#
# Last hes: 18.045368194580078
# Last hes: 18.042322158813477
# --- Model Parameters ---
# PDE Name: Allen-Cahn
# PDE Parameters: [0.0]
# Hidden Units: [50, 50, 50, 50]
# Initial Learning Rate (lr_init): 8.405130023482932e-05
# Batch size (batch_size): 2048
# BC Loss Weight: 1.0
# IC Loss Weight: 1.0
# Physics Loss Weight: 1.0
# Distillation Loss Weight: 1.0
# EWC Loss Weight: 1.0
# Activation Function: Tanh()
#
# Last hes: 16.76375961303711
# Last hes: 16.820980072021484
# --- Model Parameters ---
# PDE Name: Allen-Cahn
# PDE Parameters: [0.0]
# Hidden Units: [50, 50, 50, 50]
# Initial Learning Rate (lr_init): 7.199280632567906e-05
# Batch size (batch_size): 2048
# BC Loss Weight: 1.0
# IC Loss Weight: 1.0
# Physics Loss Weight: 1.0
# Distillation Loss Weight: 1.0
# EWC Loss Weight: 1.0
# Activation Function: Tanh()

# %% [markdown]
# # PINN

# %%
path = "models/step0/AllenCahnSingle0/PINNfullA"

subdirs = []
for entry_name in os.listdir(path):
        full_path = os.path.join(path, entry_name)
        if os.path.isdir(full_path):
                subdirs.append(entry_name)

selection = [
        "trial0",
        "trial1",
        "trial2",
        "trial3",
        "trial4",
        "trial5",
        "trial6",
        "trial7",
        "trial8",
        "trial9",
        "trial10",
        "trial11",
        "trial12",
        "trial13",
        "trial14",
        "trial15",
        "trial16",
        "trial17",
        "trial18",
        "trial19",
        "trial20",
        "best_trial"
        ]

labels = [trial for trial in os.listdir(path) if trial in selection]
filepaths=[os.path.join(path, trial) + "/train_stats.npy" for trial in subdirs if trial in selection]

plot_model_stats(filepaths=filepaths, labels=labels, to_plot=["train"])

filepaths=[os.path.join(path, trial) + "/test_stats.npy" for trial in subdirs if trial in selection]

plot_model_stats(filepaths=filepaths, labels=labels, to_plot=["test"])

# %%
path = "models/step0/AllenCahnSingle0/PINNfullA"
best_trial = "best_trial"
labels = [best_trial, best_trial]
filepaths=[os.path.join(path, best_trial) + "/train_stats.npy", os.path.join(path, best_trial) + "/test_stats.npy"]
plot_model_stats(filepaths=filepaths, labels=labels, to_plot=["train", "test"])
print_model_info(filepath=os.path.join(path, best_trial) + "/model.pth")
# Out:
# Last train loss: 0.019665714353322983
# Last test loss: 0.01999395526945591
# --- Model Parameters ---
# PDE Name: Allen-Cahn
# PDE Parameters: [0.0]
# Hidden Units: [50, 50, 50, 50]
# Initial Learning Rate (lr_init): 0.001
# Batch size (batch_size): 4096
# BC Loss Weight: 1.0
# IC Loss Weight: 1.0
# Physics Loss Weight: 1.0
# Distillation Loss Weight: 1.0
# EWC Loss Weight: 1.0
# Activation Function: Tanh()

# %%
path = "models/step0/AllenCahnSingle0/PINNfullA"
best_trial = "best_trial"
labels = [best_trial, best_trial]
filepaths=[os.path.join(path, best_trial) + "/train_stats.npy", os.path.join(path, best_trial) + "/test_stats.npy"]
plot_model_stats(filepaths=filepaths, labels=labels, to_plot=["pde"])
print_model_info(filepath=os.path.join(path, best_trial) + "/model.pth")
# Out:
# Last pde: 0.019665714353322983
# Last pde: 0.01999395526945591
# --- Model Parameters ---
# PDE Name: Allen-Cahn
# PDE Parameters: [0.0]
# Hidden Units: [50, 50, 50, 50]
# Initial Learning Rate (lr_init): 0.001
# Batch size (batch_size): 4096
# BC Loss Weight: 1.0
# IC Loss Weight: 1.0
# Physics Loss Weight: 1.0
# Distillation Loss Weight: 1.0
# EWC Loss Weight: 1.0
# Activation Function: Tanh()

# %%
path = "models/step0/AllenCahnSingle0/PINNfullA"
best_trial = "best_trial"
labels = [best_trial, best_trial]
filepaths=[os.path.join(path, best_trial) + "/train_stats.npy", os.path.join(path, best_trial) + "/test_stats.npy"]
plot_model_stats(filepaths=filepaths, labels=labels, to_plot=["out"])
print_model_info(filepath=os.path.join(path, best_trial) + "/model.pth")
# Out:
# Last out: 0.1517101675271988
# Last out: 0.14839769899845123
# --- Model Parameters ---
# PDE Name: Allen-Cahn
# PDE Parameters: [0.0]
# Hidden Units: [50, 50, 50, 50]
# Initial Learning Rate (lr_init): 0.001
# Batch size (batch_size): 4096
# BC Loss Weight: 1.0
# IC Loss Weight: 1.0
# Physics Loss Weight: 1.0
# Distillation Loss Weight: 1.0
# EWC Loss Weight: 1.0
# Activation Function: Tanh()

# %%
path = "models/step0/AllenCahnSingle0/PINNfullA"
best_trial = "best_trial"
labels = [best_trial, best_trial]
filepaths=[os.path.join(path, best_trial) + "/train_stats.npy", os.path.join(path, best_trial) + "/test_stats.npy"]
plot_model_stats(filepaths=filepaths, labels=labels, to_plot=["der"])
print_model_info(filepath=os.path.join(path, best_trial) + "/model.pth")
# Out:
# Last der: 1.7595728635787964
# Last der: 1.7465767860412598
# --- Model Parameters ---
# PDE Name: Allen-Cahn
# PDE Parameters: [0.0]
# Hidden Units: [50, 50, 50, 50]
# Initial Learning Rate (lr_init): 0.001
# Batch size (batch_size): 4096
# BC Loss Weight: 1.0
# IC Loss Weight: 1.0
# Physics Loss Weight: 1.0
# Distillation Loss Weight: 1.0
# EWC Loss Weight: 1.0
# Activation Function: Tanh()

# %%
path = "models/step0/AllenCahnSingle0/PINNfullA"
best_trial = "best_trial"
labels = [best_trial, best_trial]
filepaths=[os.path.join(path, best_trial) + "/train_stats.npy", os.path.join(path, best_trial) + "/test_stats.npy"]
plot_model_stats(filepaths=filepaths, labels=labels, to_plot=["hes"])
print_model_info(filepath=os.path.join(path, best_trial) + "/model.pth")
# Out:
# Last hes: 16.158777236938477
# Last hes: 16.180431365966797
# --- Model Parameters ---
# PDE Name: Allen-Cahn
# PDE Parameters: [0.0]
# Hidden Units: [50, 50, 50, 50]
# Initial Learning Rate (lr_init): 0.001
# Batch size (batch_size): 4096
# BC Loss Weight: 1.0
# IC Loss Weight: 1.0
# Physics Loss Weight: 1.0
# Distillation Loss Weight: 1.0
# EWC Loss Weight: 1.0
# Activation Function: Tanh()

# %% [markdown]
# # OUT boundary

# %%
path = "models/step0/AllenCahnSingle0/OUTbd"

subdirs = []
for entry_name in os.listdir(path):
        full_path = os.path.join(path, entry_name)
        if os.path.isdir(full_path):
                subdirs.append(entry_name)

selection = [
        "trial0",
        "trial1",
        "trial2",
        "trial3",
        "trial4",
        "trial5",
        "trial6",
        "trial7",
        "trial8",
        "trial9",
        "trial10",
        "trial11",
        "trial12",
        "trial13",
        "trial14",
        "trial15",
        "trial16",
        "trial17",
        "trial18",
        "trial19",
        "trial20",
        "best_trial"
        ]

labels = [trial for trial in os.listdir(path) if trial in selection]
filepaths=[os.path.join(path, trial) + "/train_stats.npy" for trial in subdirs if trial in selection]

plot_model_stats(filepaths=filepaths, labels=labels, to_plot=["train"])

filepaths=[os.path.join(path, trial) + "/test_stats.npy" for trial in subdirs if trial in selection]

plot_model_stats(filepaths=filepaths, labels=labels, to_plot=["test"])

# %%
path = "models/step0/AllenCahnSingle0/OUTbd"
best_trial = "best_trial"
labels = [best_trial, best_trial]
filepaths=[os.path.join(path, best_trial) + "/train_stats.npy", os.path.join(path, best_trial) + "/test_stats.npy"]
plot_model_stats(filepaths=filepaths, labels=labels, to_plot=["train", "test"])
print_model_info(filepath=os.path.join(path, best_trial) + "/model.pth")
# Out:
# Last train loss: 1.9524914023349993e-06
# Last test loss: 1.943240022228565e-06
# --- Model Parameters ---
# PDE Name: Allen-Cahn
# PDE Parameters: [0.0]
# Hidden Units: [50, 50, 50, 50]
# Initial Learning Rate (lr_init): 5e-05
# Batch size (batch_size): 1024
# BC Loss Weight: 1.0
# IC Loss Weight: 1.0
# Physics Loss Weight: 1.0
# Distillation Loss Weight: 1.0
# EWC Loss Weight: 1.0
# Activation Function: Tanh()

# %%
path = "models/step0/AllenCahnSingle0/OUTbd"
best_trial = "best_trial"
labels = [best_trial, best_trial]
filepaths=[os.path.join(path, best_trial) + "/train_stats.npy", os.path.join(path, best_trial) + "/test_stats.npy"]
plot_model_stats(filepaths=filepaths, labels=labels, to_plot=["pde"])
print_model_info(filepath=os.path.join(path, best_trial) + "/model.pth")
# Out:
# Last pde: 7.375868335657287e-06
# Last pde: 7.483957233489491e-06
# --- Model Parameters ---
# PDE Name: Allen-Cahn
# PDE Parameters: [0.0]
# Hidden Units: [50, 50, 50, 50]
# Initial Learning Rate (lr_init): 5e-05
# Batch size (batch_size): 1024
# BC Loss Weight: 1.0
# IC Loss Weight: 1.0
# Physics Loss Weight: 1.0
# Distillation Loss Weight: 1.0
# EWC Loss Weight: 1.0
# Activation Function: Tanh()

# %%
path = "models/step0/AllenCahnSingle0/OUTbd"
best_trial = "best_trial"
labels = [best_trial, best_trial]
filepaths=[os.path.join(path, best_trial) + "/train_stats.npy", os.path.join(path, best_trial) + "/test_stats.npy"]
plot_model_stats(filepaths=filepaths, labels=labels, to_plot=["bc"])
print_model_info(filepath=os.path.join(path, best_trial) + "/model.pth")
# Out:
# Last bc: 0.0
# Last bc: 0.0
# --- Model Parameters ---
# PDE Name: Allen-Cahn
# PDE Parameters: [0.0]
# Hidden Units: [50, 50, 50, 50]
# Initial Learning Rate (lr_init): 5e-05
# Batch size (batch_size): 1024
# BC Loss Weight: 1.0
# IC Loss Weight: 1.0
# Physics Loss Weight: 1.0
# Distillation Loss Weight: 1.0
# EWC Loss Weight: 1.0
# Activation Function: Tanh()

# %%
path = "models/step0/AllenCahnSingle0/OUTbd"
best_trial = "best_trial"
labels = [best_trial, best_trial]
filepaths=[
    os.path.join(path, best_trial) + "/train_stats.npy",
    os.path.join(path, best_trial) + "/test_stats.npy"
    ]
plot_model_stats(filepaths=filepaths, labels=labels, to_plot=["out"])
print_model_info(filepath=os.path.join(path, best_trial) + "/model.pth")
# Out:
# Last out: 1.9524914023349993e-06
# Last out: 1.943240022228565e-06
# --- Model Parameters ---
# PDE Name: Allen-Cahn
# PDE Parameters: [0.0]
# Hidden Units: [50, 50, 50, 50]
# Initial Learning Rate (lr_init): 5e-05
# Batch size (batch_size): 1024
# BC Loss Weight: 1.0
# IC Loss Weight: 1.0
# Physics Loss Weight: 1.0
# Distillation Loss Weight: 1.0
# EWC Loss Weight: 1.0
# Activation Function: Tanh()

# %%
path = "models/step0/AllenCahnSingle0/OUTbd"
best_trial = "best_trial"
labels = [best_trial, best_trial]
filepaths=[
    os.path.join(path, best_trial) + "/train_stats.npy",
    os.path.join(path, best_trial) + "/test_stats.npy"
    ]
plot_model_stats(filepaths=filepaths, labels=labels, to_plot=["der"])
print_model_info(filepath=os.path.join(path, best_trial) + "/model.pth")
# Out:
# Last der: 1.5412826538085938
# Last der: 1.5495976209640503
# --- Model Parameters ---
# PDE Name: Allen-Cahn
# PDE Parameters: [0.0]
# Hidden Units: [50, 50, 50, 50]
# Initial Learning Rate (lr_init): 5e-05
# Batch size (batch_size): 1024
# BC Loss Weight: 1.0
# IC Loss Weight: 1.0
# Physics Loss Weight: 1.0
# Distillation Loss Weight: 1.0
# EWC Loss Weight: 1.0
# Activation Function: Tanh()

# %%
path = "models/step0/AllenCahnSingle0/OUTbd"
best_trial = "trial0"
labels = [best_trial, best_trial]
filepaths=[
    os.path.join(path, best_trial) + "/train_stats.npy",
    os.path.join(path, best_trial) + "/test_stats.npy"
    ]
plot_model_stats(filepaths=filepaths, labels=labels, to_plot=["hes"])
print_model_info(filepath=os.path.join(path, best_trial) + "/model.pth")
# Out:
# Last hes: 24.43326187133789
# Last hes: 24.450510025024414
# --- Model Parameters ---
# PDE Name: Allen-Cahn
# PDE Parameters: [0.0]
# Hidden Units: [50, 50, 50, 50]
# Initial Learning Rate (lr_init): 5e-06
# Batch size (batch_size): 1024
# BC Loss Weight: 1.0
# IC Loss Weight: 1.0
# Physics Loss Weight: 1.0
# Distillation Loss Weight: 1.0
# EWC Loss Weight: 1.0
# Activation Function: Tanh()

# %% [markdown]
# # PINN with BCs

# %%
path = "models/step0/AllenCahnSingle0/PINNfullB3"

subdirs = []
for entry_name in os.listdir(path):
        full_path = os.path.join(path, entry_name)
        if os.path.isdir(full_path):
                subdirs.append(entry_name)

selection = [
        "trial0",
        "trial1",
        "trial2",
        "trial3",
        "trial4",
        "trial5",
        "trial6",
        "trial7",
        "trial8",
        "trial9",
        "trial10",
        "trial11",
        "trial12",
        "trial13",
        "trial14",
        "trial15",
        "trial16",
        "trial17",
        "trial18",
        "trial19",
        "trial20",
        "best_trial"
        ]

labels = [trial for trial in os.listdir(path) if trial in selection]
filepaths=[os.path.join(path, trial) + "/train_stats.npy" for trial in subdirs if trial in selection]

plot_model_stats(filepaths=filepaths, labels=labels, to_plot=["train"])

filepaths=[os.path.join(path, trial) + "/test_stats.npy" for trial in subdirs if trial in selection]

plot_model_stats(filepaths=filepaths, labels=labels, to_plot=["test"])

# %%
path = "models/step0/AllenCahnSingle0/PINNfullB2"
best_trial = "best_trial"
labels = [best_trial, best_trial]
filepaths=[os.path.join(path, best_trial) + "/train_stats.npy", os.path.join(path, best_trial) + "/test_stats.npy"]
plot_model_stats(filepaths=filepaths, labels=labels, to_plot=["train", "test"])
print_model_info(filepath=os.path.join(path, best_trial) + "/model.pth")
# Out:
# Last train loss: 1.7426546605747717e-07
# Last test loss: 1.7562251741765067e-07
# --- Model Parameters ---
# PDE Name: Allen-Cahn
# PDE Parameters: [0.0]
# Hidden Units: [50, 50, 50, 50]
# Initial Learning Rate (lr_init): 0.0005
# Batch size (batch_size): 1024
# BC Loss Weight: 0.02
# IC Loss Weight: 1.0
# Physics Loss Weight: 2e-06
# Distillation Loss Weight: 1.0
# EWC Loss Weight: 1.0
# Activation Function: Tanh()

# %%
path = "models/step0/AllenCahnSingle0/PINNfullB2"
best_trial = "best_trial"
labels = [best_trial, best_trial]
filepaths=[os.path.join(path, best_trial) + "/train_stats.npy", os.path.join(path, best_trial) + "/test_stats.npy"]
plot_model_stats(filepaths=filepaths, labels=labels, to_plot=["pde"])
print_model_info(filepath=os.path.join(path, best_trial) + "/model.pth")
# Out:
# Last pde: 0.04671822115778923
# Last pde: 0.047633204609155655
# --- Model Parameters ---
# PDE Name: Allen-Cahn
# PDE Parameters: [0.0]
# Hidden Units: [50, 50, 50, 50]
# Initial Learning Rate (lr_init): 0.0005
# Batch size (batch_size): 1024
# BC Loss Weight: 0.02
# IC Loss Weight: 1.0
# Physics Loss Weight: 2e-06
# Distillation Loss Weight: 1.0
# EWC Loss Weight: 1.0
# Activation Function: Tanh()

# %%
path = "models/step0/AllenCahnSingle0/PINNfullB2"
best_trial = "best_trial"
labels = [best_trial, best_trial]
filepaths=[os.path.join(path, best_trial) + "/train_stats.npy", os.path.join(path, best_trial) + "/test_stats.npy"]
plot_model_stats(filepaths=filepaths, labels=labels, to_plot=["bc"])
print_model_info(filepath=os.path.join(path, best_trial) + "/model.pth")
# Out:
# Last bc: 4.041451575176325e-06
# Last bc: 4.01780562242493e-06
# --- Model Parameters ---
# PDE Name: Allen-Cahn
# PDE Parameters: [0.0]
# Hidden Units: [50, 50, 50, 50]
# Initial Learning Rate (lr_init): 0.0005
# Batch size (batch_size): 1024
# BC Loss Weight: 0.02
# IC Loss Weight: 1.0
# Physics Loss Weight: 2e-06
# Distillation Loss Weight: 1.0
# EWC Loss Weight: 1.0
# Activation Function: Tanh()

# %%
path = "models/step0/AllenCahnSingle0/PINNfullB3"
best_trial = "trial1"
labels = [best_trial, best_trial]
filepaths=[
    os.path.join(path, best_trial) + "/train_stats.npy",
    os.path.join(path, best_trial) + "/test_stats.npy"
    ]
plot_model_stats(filepaths=filepaths, labels=labels, to_plot=["out"])
print_model_info(filepath=os.path.join(path, best_trial) + "/model.pth")
# Out:
# Last out: 0.24441370368003845
# Last out: 0.2539135217666626
# --- Model Parameters ---
# PDE Name: Allen-Cahn
# PDE Parameters: [0.0]
# Hidden Units: [50, 50, 50, 50]
# Initial Learning Rate (lr_init): 0.0001
# Batch size (batch_size): 1024
# BC Loss Weight: 0.02
# IC Loss Weight: 1.0
# Physics Loss Weight: 2e-06
# Distillation Loss Weight: 1.0
# EWC Loss Weight: 1.0
# Activation Function: Tanh()

# %%
path = "models/step0/AllenCahnSingle0/PINNfullB2"
best_trial = "best_trial"
labels = [best_trial, best_trial]
filepaths=[
    os.path.join(path, best_trial) + "/train_stats.npy",
    os.path.join(path, best_trial) + "/test_stats.npy"
    ]
plot_model_stats(filepaths=filepaths, labels=labels, to_plot=["der"])
print_model_info(filepath=os.path.join(path, best_trial) + "/model.pth")
# Out:
# Last der: 1.8282482624053955
# Last der: 1.8577139377593994
# --- Model Parameters ---
# PDE Name: Allen-Cahn
# PDE Parameters: [0.0]
# Hidden Units: [50, 50, 50, 50]
# Initial Learning Rate (lr_init): 5e-05
# Batch size (batch_size): 1024
# BC Loss Weight: 0.02
# IC Loss Weight: 1.0
# Physics Loss Weight: 2e-06
# Distillation Loss Weight: 1.0
# EWC Loss Weight: 1.0
# Activation Function: Tanh()

# %%
path = "models/step0/AllenCahnSingle0/PINNfullB"
best_trial = "best_trial"
labels = [best_trial, best_trial]
filepaths=[
    os.path.join(path, best_trial) + "/train_stats.npy",
    os.path.join(path, best_trial) + "/test_stats.npy"
    ]
plot_model_stats(filepaths=filepaths, labels=labels, to_plot=["hes"])
print_model_info(filepath=os.path.join(path, best_trial) + "/model.pth")
# Out:
# Last hes: 18.744361877441406
# Last hes: 18.47345542907715
# --- Model Parameters ---
# PDE Name: Allen-Cahn
# PDE Parameters: [0.0]
# Hidden Units: [50, 50, 50, 50]
# Initial Learning Rate (lr_init): 5e-05
# Batch size (batch_size): 1024
# BC Loss Weight: 0.02
# IC Loss Weight: 1.0
# Physics Loss Weight: 2e-06
# Distillation Loss Weight: 1.0
# EWC Loss Weight: 1.0
# Activation Function: Tanh()
