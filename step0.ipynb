# %%
from plot_utils import plot_points, plot_model_stats, print_model_info, plot_loss
import os
from evaluate import evaluate

# %%
plot_points('data/train/0/full/random_dom.pth', points_idx = 0, labels_idx = 1)

# %% [markdown]
# # OUT

# %%
path = "models/step0/AllenCahnSingle0/OUTfullAAA"

subdirs = []
for entry_name in os.listdir(path):
        full_path = os.path.join(path, entry_name)
        if os.path.isdir(full_path):
                subdirs.append(entry_name)

selection = [
        "trial0",
        "trial1",
        "trial2",
        "trial3",
        "trial4",
        "trial5",
        "trial6",
        "trial7",
        "trial8",
        "trial9",
        "trial10",
        "trial11",
        "trial12",
        "trial13",
        "trial14",
        "trial15",
        "trial16",
        "trial17",
        "trial18",
        "trial19",
        "trial20",
        "best_trial"
        ]

labels = [trial for trial in os.listdir(path) if trial in selection]
filepaths=[os.path.join(path, trial) + "/train_stats.npy" for trial in subdirs if trial in selection]

plot_model_stats(filepaths=filepaths, labels=labels, to_plot=["train"])

filepaths=[os.path.join(path, trial) + "/test_stats.npy" for trial in subdirs if trial in selection]

plot_model_stats(filepaths=filepaths, labels=labels, to_plot=["test"])

# %%
path = "models/step0/AllenCahnSingle0/OUTfullA"
best_trial = "best_trial"
labels = [best_trial, best_trial]
filepaths=[os.path.join(path, best_trial) + "/train_stats.npy", os.path.join(path, best_trial) + "/test_stats.npy"]
plot_model_stats(filepaths=filepaths, labels=labels, to_plot=["train", "test"])
print_model_info(filepath=os.path.join(path, best_trial) + "/model.pth")
print("")
path = "models/step0/AllenCahnSingle0/OUTfullAA"
best_trial = "best_trial"
labels = [best_trial, best_trial]
filepaths=[os.path.join(path, best_trial) + "/train_stats.npy", os.path.join(path, best_trial) + "/test_stats.npy"]
plot_model_stats(filepaths=filepaths, labels=labels, to_plot=["train", "test"])
print_model_info(filepath=os.path.join(path, best_trial) + "/model.pth")
print("")
path = "models/step0/AllenCahnSingle0/OUTfullAAA"
best_trial = "best_trial"
labels = [best_trial, best_trial]
filepaths=[os.path.join(path, best_trial) + "/train_stats.npy", os.path.join(path, best_trial) + "/test_stats.npy"]
plot_model_stats(filepaths=filepaths, labels=labels, to_plot=["train", "test"])
print_model_info(filepath=os.path.join(path, best_trial) + "/model.pth")
# Out:
# Last train loss: 0.02425762638449669
# Last test loss: 0.02381928637623787
# --- Model Parameters ---
# PDE Name: Allen-Cahn
# PDE Parameters: [0.0]
# Hidden Units: [50, 50, 50, 50]
# Initial Learning Rate (lr_init): 0.0008866251448974667
# Batch size (batch_size): 2048
# BC Loss Weight: 1.0
# IC Loss Weight: 1.0
# Physics Loss Weight: 1.0
# Distillation Loss Weight: 1.0
# EWC Loss Weight: 1.0
# Activation Function: Tanh()
#
# Last train loss: 0.21409742534160614
# Last test loss: 0.2109573483467102
# --- Model Parameters ---
# PDE Name: Allen-Cahn
# PDE Parameters: [0.0]
# Hidden Units: [50, 50, 50, 50]
# Initial Learning Rate (lr_init): 8.405130023482932e-05
# Batch size (batch_size): 2048
# BC Loss Weight: 1.0
# IC Loss Weight: 1.0
# Physics Loss Weight: 1.0
# Distillation Loss Weight: 1.0
# EWC Loss Weight: 1.0
# Activation Function: Tanh()
#
# Last train loss: 0.12777350842952728
# Last test loss: 0.12453275173902512
# --- Model Parameters ---
# PDE Name: Allen-Cahn
# PDE Parameters: [0.0]
# Hidden Units: [50, 50, 50, 50]
# Initial Learning Rate (lr_init): 7.199280632567906e-05
# Batch size (batch_size): 2048
# BC Loss Weight: 1.0
# IC Loss Weight: 1.0
# Physics Loss Weight: 1.0
# Distillation Loss Weight: 1.0
# EWC Loss Weight: 1.0
# Activation Function: Tanh()

# %%
path = "models/step0/AllenCahnSingle0/OUTfullA"
best_trial = "best_trial"
labels = [best_trial, best_trial]
filepaths=[os.path.join(path, best_trial) + "/train_stats.npy", os.path.join(path, best_trial) + "/test_stats.npy"]
plot_model_stats(filepaths=filepaths, labels=labels, to_plot=["pde"])
print_model_info(filepath=os.path.join(path, best_trial) + "/model.pth")
print("")
path = "models/step0/AllenCahnSingle0/OUTfullAA"
best_trial = "best_trial"
labels = [best_trial, best_trial]
filepaths=[os.path.join(path, best_trial) + "/train_stats.npy", os.path.join(path, best_trial) + "/test_stats.npy"]
plot_model_stats(filepaths=filepaths, labels=labels, to_plot=["pde"])
print_model_info(filepath=os.path.join(path, best_trial) + "/model.pth")
print("")
path = "models/step0/AllenCahnSingle0/OUTfullAAA"
best_trial = "best_trial"
labels = [best_trial, best_trial]
filepaths=[os.path.join(path, best_trial) + "/train_stats.npy", os.path.join(path, best_trial) + "/test_stats.npy"]
plot_model_stats(filepaths=filepaths, labels=labels, to_plot=["pde"])
print_model_info(filepath=os.path.join(path, best_trial) + "/model.pth")
# Out:
# Last pde: 0.0408627912402153
# Last pde: 0.0394463986158371
# --- Model Parameters ---
# PDE Name: Allen-Cahn
# PDE Parameters: [0.0]
# Hidden Units: [50, 50, 50, 50]
# Initial Learning Rate (lr_init): 0.0008866251448974667
# Batch size (batch_size): 2048
# BC Loss Weight: 1.0
# IC Loss Weight: 1.0
# Physics Loss Weight: 1.0
# Distillation Loss Weight: 1.0
# EWC Loss Weight: 1.0
# Activation Function: Tanh()
#
# Last pde: 0.0314902663230896
# Last pde: 0.032878533005714417
# --- Model Parameters ---
# PDE Name: Allen-Cahn
# PDE Parameters: [0.0]
# Hidden Units: [50, 50, 50, 50]
# Initial Learning Rate (lr_init): 8.405130023482932e-05
# Batch size (batch_size): 2048
# BC Loss Weight: 1.0
# IC Loss Weight: 1.0
# Physics Loss Weight: 1.0
# Distillation Loss Weight: 1.0
# EWC Loss Weight: 1.0
# Activation Function: Tanh()
#
# Last pde: 0.029337119311094284
# Last pde: 0.028764579445123672
# --- Model Parameters ---
# PDE Name: Allen-Cahn
# PDE Parameters: [0.0]
# Hidden Units: [50, 50, 50, 50]
# Initial Learning Rate (lr_init): 7.199280632567906e-05
# Batch size (batch_size): 2048
# BC Loss Weight: 1.0
# IC Loss Weight: 1.0
# Physics Loss Weight: 1.0
# Distillation Loss Weight: 1.0
# EWC Loss Weight: 1.0
# Activation Function: Tanh()

# %%
path = "models/step0/AllenCahnSingle0/OUTfullA"
best_trial = "best_trial"
labels = [best_trial, best_trial]
filepaths=[os.path.join(path, best_trial) + "/train_stats.npy", os.path.join(path, best_trial) + "/test_stats.npy"]
plot_model_stats(filepaths=filepaths, labels=labels, to_plot=["out"])
print_model_info(filepath=os.path.join(path, best_trial) + "/model.pth")
print("")
path = "models/step0/AllenCahnSingle0/OUTfullAA"
best_trial = "best_trial"
labels = [best_trial, best_trial]
filepaths=[os.path.join(path, best_trial) + "/train_stats.npy", os.path.join(path, best_trial) + "/test_stats.npy"]
plot_model_stats(filepaths=filepaths, labels=labels, to_plot=["out"])
print_model_info(filepath=os.path.join(path, best_trial) + "/model.pth")
print("")
path = "models/step0/AllenCahnSingle0/OUTfullAAA"
best_trial = "best_trial"
labels = [best_trial, best_trial]
filepaths=[os.path.join(path, best_trial) + "/train_stats.npy", os.path.join(path, best_trial) + "/test_stats.npy"]
plot_model_stats(filepaths=filepaths, labels=labels, to_plot=["out"])
print_model_info(filepath=os.path.join(path, best_trial) + "/model.pth")
# Out:
# Last out: 0.02425762638449669
# Last out: 0.02381928637623787
# --- Model Parameters ---
# PDE Name: Allen-Cahn
# PDE Parameters: [0.0]
# Hidden Units: [50, 50, 50, 50]
# Initial Learning Rate (lr_init): 0.0008866251448974667
# Batch size (batch_size): 2048
# BC Loss Weight: 1.0
# IC Loss Weight: 1.0
# Physics Loss Weight: 1.0
# Distillation Loss Weight: 1.0
# EWC Loss Weight: 1.0
# Activation Function: Tanh()
#
# Last out: 0.21409742534160614
# Last out: 0.2109573483467102
# --- Model Parameters ---
# PDE Name: Allen-Cahn
# PDE Parameters: [0.0]
# Hidden Units: [50, 50, 50, 50]
# Initial Learning Rate (lr_init): 8.405130023482932e-05
# Batch size (batch_size): 2048
# BC Loss Weight: 1.0
# IC Loss Weight: 1.0
# Physics Loss Weight: 1.0
# Distillation Loss Weight: 1.0
# EWC Loss Weight: 1.0
# Activation Function: Tanh()
#
# Last out: 0.12777350842952728
# Last out: 0.12453275173902512
# --- Model Parameters ---
# PDE Name: Allen-Cahn
# PDE Parameters: [0.0]
# Hidden Units: [50, 50, 50, 50]
# Initial Learning Rate (lr_init): 7.199280632567906e-05
# Batch size (batch_size): 2048
# BC Loss Weight: 1.0
# IC Loss Weight: 1.0
# Physics Loss Weight: 1.0
# Distillation Loss Weight: 1.0
# EWC Loss Weight: 1.0
# Activation Function: Tanh()

# %%
path = "models/step0/AllenCahnSingle0/OUTfullA"
best_trial = "best_trial"
labels = [best_trial, best_trial]
filepaths=[os.path.join(path, best_trial) + "/train_stats.npy", os.path.join(path, best_trial) + "/test_stats.npy"]
plot_model_stats(filepaths=filepaths, labels=labels, to_plot=["der"])
print_model_info(filepath=os.path.join(path, best_trial) + "/model.pth")
print("")
path = "models/step0/AllenCahnSingle0/OUTfullAA"
best_trial = "best_trial"
labels = [best_trial, best_trial]
filepaths=[os.path.join(path, best_trial) + "/train_stats.npy", os.path.join(path, best_trial) + "/test_stats.npy"]
plot_model_stats(filepaths=filepaths, labels=labels, to_plot=["der"])
print_model_info(filepath=os.path.join(path, best_trial) + "/model.pth")
print("")
path = "models/step0/AllenCahnSingle0/OUTfullAAA"
best_trial = "best_trial"
labels = [best_trial, best_trial]
filepaths=[os.path.join(path, best_trial) + "/train_stats.npy", os.path.join(path, best_trial) + "/test_stats.npy"]
plot_model_stats(filepaths=filepaths, labels=labels, to_plot=["der"])
print_model_info(filepath=os.path.join(path, best_trial) + "/model.pth")
# Out:
# Last der: 1.843743920326233
# Last der: 1.8175780773162842
# --- Model Parameters ---
# PDE Name: Allen-Cahn
# PDE Parameters: [0.0]
# Hidden Units: [50, 50, 50, 50]
# Initial Learning Rate (lr_init): 0.0008866251448974667
# Batch size (batch_size): 2048
# BC Loss Weight: 1.0
# IC Loss Weight: 1.0
# Physics Loss Weight: 1.0
# Distillation Loss Weight: 1.0
# EWC Loss Weight: 1.0
# Activation Function: Tanh()
#
# Last der: 1.8707879781723022
# Last der: 1.8609167337417603
# --- Model Parameters ---
# PDE Name: Allen-Cahn
# PDE Parameters: [0.0]
# Hidden Units: [50, 50, 50, 50]
# Initial Learning Rate (lr_init): 8.405130023482932e-05
# Batch size (batch_size): 2048
# BC Loss Weight: 1.0
# IC Loss Weight: 1.0
# Physics Loss Weight: 1.0
# Distillation Loss Weight: 1.0
# EWC Loss Weight: 1.0
# Activation Function: Tanh()
#
# Last der: 2.1008667945861816
# Last der: 2.0728225708007812
# --- Model Parameters ---
# PDE Name: Allen-Cahn
# PDE Parameters: [0.0]
# Hidden Units: [50, 50, 50, 50]
# Initial Learning Rate (lr_init): 7.199280632567906e-05
# Batch size (batch_size): 2048
# BC Loss Weight: 1.0
# IC Loss Weight: 1.0
# Physics Loss Weight: 1.0
# Distillation Loss Weight: 1.0
# EWC Loss Weight: 1.0
# Activation Function: Tanh()

# %%
path = "models/step0/AllenCahnSingle0/OUTfullA"
best_trial = "best_trial"
labels = [best_trial, best_trial]
filepaths=[os.path.join(path, best_trial) + "/train_stats.npy", os.path.join(path, best_trial) + "/test_stats.npy"]
plot_model_stats(filepaths=filepaths, labels=labels, to_plot=["hes"])
print_model_info(filepath=os.path.join(path, best_trial) + "/model.pth")
print("")
path = "models/step0/AllenCahnSingle0/OUTfullAA"
best_trial = "best_trial"
labels = [best_trial, best_trial]
filepaths=[os.path.join(path, best_trial) + "/train_stats.npy", os.path.join(path, best_trial) + "/test_stats.npy"]
plot_model_stats(filepaths=filepaths, labels=labels, to_plot=["hes"])
print_model_info(filepath=os.path.join(path, best_trial) + "/model.pth")
print("")
path = "models/step0/AllenCahnSingle0/OUTfullAAA"
best_trial = "best_trial"
labels = [best_trial, best_trial]
filepaths=[os.path.join(path, best_trial) + "/train_stats.npy", os.path.join(path, best_trial) + "/test_stats.npy"]
plot_model_stats(filepaths=filepaths, labels=labels, to_plot=["hes"])
print_model_info(filepath=os.path.join(path, best_trial) + "/model.pth")
# Out:
# Last hes: 17.599937438964844
# Last hes: 18.11784553527832
# --- Model Parameters ---
# PDE Name: Allen-Cahn
# PDE Parameters: [0.0]
# Hidden Units: [50, 50, 50, 50]
# Initial Learning Rate (lr_init): 0.0008866251448974667
# Batch size (batch_size): 2048
# BC Loss Weight: 1.0
# IC Loss Weight: 1.0
# Physics Loss Weight: 1.0
# Distillation Loss Weight: 1.0
# EWC Loss Weight: 1.0
# Activation Function: Tanh()
#
# Last hes: 18.045368194580078
# Last hes: 18.042322158813477
# --- Model Parameters ---
# PDE Name: Allen-Cahn
# PDE Parameters: [0.0]
# Hidden Units: [50, 50, 50, 50]
# Initial Learning Rate (lr_init): 8.405130023482932e-05
# Batch size (batch_size): 2048
# BC Loss Weight: 1.0
# IC Loss Weight: 1.0
# Physics Loss Weight: 1.0
# Distillation Loss Weight: 1.0
# EWC Loss Weight: 1.0
# Activation Function: Tanh()
#
# Last hes: 16.76375961303711
# Last hes: 16.820980072021484
# --- Model Parameters ---
# PDE Name: Allen-Cahn
# PDE Parameters: [0.0]
# Hidden Units: [50, 50, 50, 50]
# Initial Learning Rate (lr_init): 7.199280632567906e-05
# Batch size (batch_size): 2048
# BC Loss Weight: 1.0
# IC Loss Weight: 1.0
# Physics Loss Weight: 1.0
# Distillation Loss Weight: 1.0
# EWC Loss Weight: 1.0
# Activation Function: Tanh()

# %% [markdown]
# # PINN

# %%
path = "models/step0/AllenCahnSingle0/PINNfullAAAA"

subdirs = []
for entry_name in os.listdir(path):
        full_path = os.path.join(path, entry_name)
        if os.path.isdir(full_path):
                subdirs.append(entry_name)

selection = [
        "trial0",
        "trial1",
        "trial2",
        "trial3",
        "trial4",
        "trial5",
        "trial6",
        "trial7",
        "trial8",
        "trial9",
        "trial10",
        "trial11",
        "trial12",
        "trial13",
        "trial14",
        "trial15",
        "trial16",
        "trial17",
        "trial18",
        "trial19",
        "trial20",
        "best_trial"
        ]

labels = [trial for trial in os.listdir(path) if trial in selection]
filepaths=[os.path.join(path, trial) + "/train_stats.npy" for trial in subdirs if trial in selection]

plot_model_stats(filepaths=filepaths, labels=labels, to_plot=["train"])

filepaths=[os.path.join(path, trial) + "/test_stats.npy" for trial in subdirs if trial in selection]

plot_model_stats(filepaths=filepaths, labels=labels, to_plot=["test"])

# %%
path = "models/step0/AllenCahnSingle0/PINNfullA"
best_trial = "best_trial"
labels = [best_trial, best_trial]
filepaths=[os.path.join(path, best_trial) + "/train_stats.npy", os.path.join(path, best_trial) + "/test_stats.npy"]
plot_model_stats(filepaths=filepaths, labels=labels, to_plot=["train", "test"])
print_model_info(filepath=os.path.join(path, best_trial) + "/model.pth")
print("")
path = "models/step0/AllenCahnSingle0/PINNfullAA"
best_trial = "trial3"
labels = [best_trial, best_trial]
filepaths=[os.path.join(path, best_trial) + "/train_stats.npy", os.path.join(path, best_trial) + "/test_stats.npy"]
plot_model_stats(filepaths=filepaths, labels=labels, to_plot=["train", "test"])
print_model_info(filepath=os.path.join(path, best_trial) + "/model.pth")
print("")
path = "models/step0/AllenCahnSingle0/PINNfullAAA"
best_trial = "best_trial"
labels = [best_trial, best_trial]
filepaths=[os.path.join(path, best_trial) + "/train_stats.npy", os.path.join(path, best_trial) + "/test_stats.npy"]
plot_model_stats(filepaths=filepaths, labels=labels, to_plot=["train", "test"])
print_model_info(filepath=os.path.join(path, best_trial) + "/model.pth")
# Out:
# Last train loss: 0.018776219338178635
# Last test loss: 0.01903233304619789
# --- Model Parameters ---
# PDE Name: Allen-Cahn
# PDE Parameters: [0.0]
# Hidden Units: [50, 50, 50, 50]
# Initial Learning Rate (lr_init): 0.0005920681917142015
# Batch size (batch_size): 2048
# BC Loss Weight: 1.0
# IC Loss Weight: 1.0
# Physics Loss Weight: 1.0
# Distillation Loss Weight: 1.0
# EWC Loss Weight: 1.0
# Activation Function: Tanh()
#
# Last train loss: 0.04618880897760391
# Last test loss: 0.04782265052199364
# --- Model Parameters ---
# PDE Name: Allen-Cahn
# PDE Parameters: [0.0]
# Hidden Units: [50, 50, 50, 50]
# Initial Learning Rate (lr_init): 1.677822417069516e-05
# Batch size (batch_size): 2048
# BC Loss Weight: 1.0
# IC Loss Weight: 1.0
# Physics Loss Weight: 1.0
# Distillation Loss Weight: 1.0
# EWC Loss Weight: 1.0
# Activation Function: Tanh()
#
# Last train loss: 0.050002358853816986
# Last test loss: 0.05119919776916504
# --- Model Parameters ---
# PDE Name: Allen-Cahn
# PDE Parameters: [0.0]
# Hidden Units: [50, 50, 50, 50]
# Initial Learning Rate (lr_init): 1e-06
# Batch size (batch_size): 2048
# BC Loss Weight: 1.0
# IC Loss Weight: 1.0
# Physics Loss Weight: 1.0
# Distillation Loss Weight: 1.0
# EWC Loss Weight: 1.0
# Activation Function: Tanh()

# %%
path = "models/step0/AllenCahnSingle0/PINNfullA"
best_trial = "best_trial"
labels = [best_trial, best_trial]
filepaths=[os.path.join(path, best_trial) + "/train_stats.npy", os.path.join(path, best_trial) + "/test_stats.npy"]
plot_model_stats(filepaths=filepaths, labels=labels, to_plot=["pde"])
print_model_info(filepath=os.path.join(path, best_trial) + "/model.pth")
print("")
path = "models/step0/AllenCahnSingle0/PINNfullAA"
best_trial = "best_trial"
labels = [best_trial, best_trial]
filepaths=[os.path.join(path, best_trial) + "/train_stats.npy", os.path.join(path, best_trial) + "/test_stats.npy"]
plot_model_stats(filepaths=filepaths, labels=labels, to_plot=["pde"])
print_model_info(filepath=os.path.join(path, best_trial) + "/model.pth")
#print("")
#path = "models/step0/AllenCahnSingle0/PINNfullAAA"
#best_trial = "best_trial"
#labels = [best_trial, best_trial]
#filepaths=[os.path.join(path, best_trial) + "/train_stats.npy", os.path.join(path, best_trial) + "/test_stats.npy"]
#plot_model_stats(filepaths=filepaths, labels=labels, to_plot=["pde"])
#print_model_info(filepath=os.path.join(path, best_trial) + "/model.pth")
# Out:
# Last pde: 0.018776219338178635
# Last pde: 0.01903233304619789
# --- Model Parameters ---
# PDE Name: Allen-Cahn
# PDE Parameters: [0.0]
# Hidden Units: [50, 50, 50, 50]
# Initial Learning Rate (lr_init): 0.0005920681917142015
# Batch size (batch_size): 2048
# BC Loss Weight: 1.0
# IC Loss Weight: 1.0
# Physics Loss Weight: 1.0
# Distillation Loss Weight: 1.0
# EWC Loss Weight: 1.0
# Activation Function: Tanh()
#
# Last pde: 0.03369835764169693
# Last pde: 0.035110823810100555
# --- Model Parameters ---
# PDE Name: Allen-Cahn
# PDE Parameters: [0.0]
# Hidden Units: [50, 50, 50, 50]
# Initial Learning Rate (lr_init): 9.507592095063772e-05
# Batch size (batch_size): 2048
# BC Loss Weight: 1.0
# IC Loss Weight: 1.0
# Physics Loss Weight: 1.0
# Distillation Loss Weight: 1.0
# EWC Loss Weight: 1.0
# Activation Function: Tanh()

# %%
path = "models/step0/AllenCahnSingle0/PINNfullA"
best_trial = "best_trial"
labels = [best_trial, best_trial]
filepaths=[os.path.join(path, best_trial) + "/train_stats.npy", os.path.join(path, best_trial) + "/test_stats.npy"]
plot_model_stats(filepaths=filepaths, labels=labels, to_plot=["out"])
print_model_info(filepath=os.path.join(path, best_trial) + "/model.pth")
print("")
path = "models/step0/AllenCahnSingle0/PINNfullAA"
best_trial = "best_trial"
labels = [best_trial, best_trial]
filepaths=[os.path.join(path, best_trial) + "/train_stats.npy", os.path.join(path, best_trial) + "/test_stats.npy"]
plot_model_stats(filepaths=filepaths, labels=labels, to_plot=["out"])
print_model_info(filepath=os.path.join(path, best_trial) + "/model.pth")
#print("")
#path = "models/step0/AllenCahnSingle0/PINNfullAAA"
#best_trial = "best_trial"
#labels = [best_trial, best_trial]
#filepaths=[os.path.join(path, best_trial) + "/train_stats.npy", os.path.join(path, best_trial) + "/test_stats.npy"]
#plot_model_stats(filepaths=filepaths, labels=labels, to_plot=["hes"])
#print_model_info(filepath=os.path.join(path, best_trial) + "/model.pth")
# Out:
# Last out: 0.14632712304592133
# Last out: 0.14310482144355774
# --- Model Parameters ---
# PDE Name: Allen-Cahn
# PDE Parameters: [0.0]
# Hidden Units: [50, 50, 50, 50]
# Initial Learning Rate (lr_init): 0.0005920681917142015
# Batch size (batch_size): 2048
# BC Loss Weight: 1.0
# IC Loss Weight: 1.0
# Physics Loss Weight: 1.0
# Distillation Loss Weight: 1.0
# EWC Loss Weight: 1.0
# Activation Function: Tanh()
#
# Last out: 0.22149403393268585
# Last out: 0.21801504492759705
# --- Model Parameters ---
# PDE Name: Allen-Cahn
# PDE Parameters: [0.0]
# Hidden Units: [50, 50, 50, 50]
# Initial Learning Rate (lr_init): 9.507592095063772e-05
# Batch size (batch_size): 2048
# BC Loss Weight: 1.0
# IC Loss Weight: 1.0
# Physics Loss Weight: 1.0
# Distillation Loss Weight: 1.0
# EWC Loss Weight: 1.0
# Activation Function: Tanh()

# %%
path = "models/step0/AllenCahnSingle0/PINNfullA"
best_trial = "best_trial"
labels = [best_trial, best_trial]
filepaths=[os.path.join(path, best_trial) + "/train_stats.npy", os.path.join(path, best_trial) + "/test_stats.npy"]
plot_model_stats(filepaths=filepaths, labels=labels, to_plot=["der"])
print_model_info(filepath=os.path.join(path, best_trial) + "/model.pth")
print("")
path = "models/step0/AllenCahnSingle0/PINNfullAA"
best_trial = "best_trial"
labels = [best_trial, best_trial]
filepaths=[os.path.join(path, best_trial) + "/train_stats.npy", os.path.join(path, best_trial) + "/test_stats.npy"]
plot_model_stats(filepaths=filepaths, labels=labels, to_plot=["der"])
print_model_info(filepath=os.path.join(path, best_trial) + "/model.pth")
#print("")
#path = "models/step0/AllenCahnSingle0/PINNfullAAA"
#best_trial = "best_trial"
#labels = [best_trial, best_trial]
#filepaths=[os.path.join(path, best_trial) + "/train_stats.npy", os.path.join(path, best_trial) + "/test_stats.npy"]
#plot_model_stats(filepaths=filepaths, labels=labels, to_plot=["hes"])
#print_model_info(filepath=os.path.join(path, best_trial) + "/model.pth")
# Out:
# Last der: 1.7174049615859985
# Last der: 1.7048578262329102
# --- Model Parameters ---
# PDE Name: Allen-Cahn
# PDE Parameters: [0.0]
# Hidden Units: [50, 50, 50, 50]
# Initial Learning Rate (lr_init): 0.0005920681917142015
# Batch size (batch_size): 2048
# BC Loss Weight: 1.0
# IC Loss Weight: 1.0
# Physics Loss Weight: 1.0
# Distillation Loss Weight: 1.0
# EWC Loss Weight: 1.0
# Activation Function: Tanh()
#
# Last der: 1.8658685684204102
# Last der: 1.8571882247924805
# --- Model Parameters ---
# PDE Name: Allen-Cahn
# PDE Parameters: [0.0]
# Hidden Units: [50, 50, 50, 50]
# Initial Learning Rate (lr_init): 9.507592095063772e-05
# Batch size (batch_size): 2048
# BC Loss Weight: 1.0
# IC Loss Weight: 1.0
# Physics Loss Weight: 1.0
# Distillation Loss Weight: 1.0
# EWC Loss Weight: 1.0
# Activation Function: Tanh()

# %%
path = "models/step0/AllenCahnSingle0/PINNfullA"
best_trial = "best_trial"
labels = [best_trial, best_trial]
filepaths=[os.path.join(path, best_trial) + "/train_stats.npy", os.path.join(path, best_trial) + "/test_stats.npy"]
plot_model_stats(filepaths=filepaths, labels=labels, to_plot=["hes"])
print_model_info(filepath=os.path.join(path, best_trial) + "/model.pth")
print("")
path = "models/step0/AllenCahnSingle0/PINNfullAA"
best_trial = "best_trial"
labels = [best_trial, best_trial]
filepaths=[os.path.join(path, best_trial) + "/train_stats.npy", os.path.join(path, best_trial) + "/test_stats.npy"]
plot_model_stats(filepaths=filepaths, labels=labels, to_plot=["hes"])
print_model_info(filepath=os.path.join(path, best_trial) + "/model.pth")
#print("")
#path = "models/step0/AllenCahnSingle0/PINNfullAAA"
#best_trial = "best_trial"
#labels = [best_trial, best_trial]
#filepaths=[os.path.join(path, best_trial) + "/train_stats.npy", os.path.join(path, best_trial) + "/test_stats.npy"]
#plot_model_stats(filepaths=filepaths, labels=labels, to_plot=["hes"])
#print_model_info(filepath=os.path.join(path, best_trial) + "/model.pth")
# Out:
# Last hes: 15.62337875366211
# Last hes: 15.652952194213867
# --- Model Parameters ---
# PDE Name: Allen-Cahn
# PDE Parameters: [0.0]
# Hidden Units: [50, 50, 50, 50]
# Initial Learning Rate (lr_init): 0.0005920681917142015
# Batch size (batch_size): 2048
# BC Loss Weight: 1.0
# IC Loss Weight: 1.0
# Physics Loss Weight: 1.0
# Distillation Loss Weight: 1.0
# EWC Loss Weight: 1.0
# Activation Function: Tanh()
#
# Last hes: 18.092193603515625
# Last hes: 18.08626937866211
# --- Model Parameters ---
# PDE Name: Allen-Cahn
# PDE Parameters: [0.0]
# Hidden Units: [50, 50, 50, 50]
# Initial Learning Rate (lr_init): 9.507592095063772e-05
# Batch size (batch_size): 2048
# BC Loss Weight: 1.0
# IC Loss Weight: 1.0
# Physics Loss Weight: 1.0
# Distillation Loss Weight: 1.0
# EWC Loss Weight: 1.0
# Activation Function: Tanh()

# %% [markdown]
# # OUT with BCs

# %%
path = "models/step0/AllenCahnSingle0/OUTfullB"

subdirs = []
for entry_name in os.listdir(path):
        full_path = os.path.join(path, entry_name)
        if os.path.isdir(full_path):
                subdirs.append(entry_name)

selection = [
        "trial0",
        "trial1",
        "trial2",
        "trial3",
        "trial4",
        "trial5",
        "trial6",
        "trial7",
        "trial8",
        "trial9",
        "trial10",
        "trial11",
        "trial12",
        "trial13",
        "trial14",
        "trial15",
        "trial16",
        "trial17",
        "trial18",
        "trial19",
        "trial20",
        "best_trial"
        ]

labels = [trial for trial in os.listdir(path) if trial in selection]
filepaths=[os.path.join(path, trial) + "/train_stats.npy" for trial in subdirs if trial in selection]

plot_model_stats(filepaths=filepaths, labels=labels, to_plot=["train"])

filepaths=[os.path.join(path, trial) + "/test_stats.npy" for trial in subdirs if trial in selection]

plot_model_stats(filepaths=filepaths, labels=labels, to_plot=["test"])

# %%
best_trial = "best_trial"
labels = [best_trial, best_trial]
filepaths=[os.path.join(path, best_trial) + "/train_stats.npy", os.path.join(path, best_trial) + "/test_stats.npy"]
plot_model_stats(filepaths=filepaths, labels=labels, to_plot=["train", "test"])
print_model_info(filepath=os.path.join(path, best_trial) + "/model.pth")
# Out:
# Last train loss: 6.7171290538681205e-06
# Last test loss: 6.712555659760255e-06
# --- Model Parameters ---
# PDE Name: Allen-Cahn
# PDE Parameters: [0.0]
# Hidden Units: [50, 50, 50, 50]
# Initial Learning Rate (lr_init): 0.0005433864190414326
# Batch size (batch_size): 2048
# BC Loss Weight: 0.0033884507088243615
# IC Loss Weight: 1.0
# Physics Loss Weight: 0.0016602264079493237
# Distillation Loss Weight: 1.0
# EWC Loss Weight: 1.0
# Activation Function: Tanh()

# %%
best_trial = "best_trial"
labels = [best_trial, best_trial]
filepaths=[os.path.join(path, best_trial) + "/train_stats.npy", os.path.join(path, best_trial) + "/test_stats.npy"]
plot_model_stats(filepaths=filepaths, labels=labels, to_plot=["pde"])
print_model_info(filepath=os.path.join(path, best_trial) + "/model.pth")
# Out:
# Last pde: 0.025515085086226463
# Last pde: 0.024789540097117424
# --- Model Parameters ---
# PDE Name: Allen-Cahn
# PDE Parameters: [0.0]
# Hidden Units: [50, 50, 50, 50]
# Initial Learning Rate (lr_init): 0.0005433864190414326
# Batch size (batch_size): 2048
# BC Loss Weight: 0.0033884507088243615
# IC Loss Weight: 1.0
# Physics Loss Weight: 0.0016602264079493237
# Distillation Loss Weight: 1.0
# EWC Loss Weight: 1.0
# Activation Function: Tanh()

# %%
best_trial = "best_trial"
labels = [best_trial, best_trial]
filepaths=[os.path.join(path, best_trial) + "/train_stats.npy", os.path.join(path, best_trial) + "/test_stats.npy"]
plot_model_stats(filepaths=filepaths, labels=labels, to_plot=["out"])
print_model_info(filepath=os.path.join(path, best_trial) + "/model.pth")
# Out:
# Last out: 0.0019492290448397398
# Last out: 0.0019813720136880875
# --- Model Parameters ---
# PDE Name: Allen-Cahn
# PDE Parameters: [0.0]
# Hidden Units: [50, 50, 50, 50]
# Initial Learning Rate (lr_init): 0.0005433864190414326
# Batch size (batch_size): 2048
# BC Loss Weight: 0.0033884507088243615
# IC Loss Weight: 1.0
# Physics Loss Weight: 0.0016602264079493237
# Distillation Loss Weight: 1.0
# EWC Loss Weight: 1.0
# Activation Function: Tanh()

# %%
best_trial = "best_trial"
labels = [best_trial, best_trial]
filepaths=[os.path.join(path, best_trial) + "/train_stats.npy", os.path.join(path, best_trial) + "/test_stats.npy"]
plot_model_stats(filepaths=filepaths, labels=labels, to_plot=["der"])
print_model_info(filepath=os.path.join(path, best_trial) + "/model.pth")
# Out:
# Last der: 1.8692492246627808
# Last der: 1.8500806093215942
# --- Model Parameters ---
# PDE Name: Allen-Cahn
# PDE Parameters: [0.0]
# Hidden Units: [50, 50, 50, 50]
# Initial Learning Rate (lr_init): 0.0005433864190414326
# Batch size (batch_size): 2048
# BC Loss Weight: 0.0033884507088243615
# IC Loss Weight: 1.0
# Physics Loss Weight: 0.0016602264079493237
# Distillation Loss Weight: 1.0
# EWC Loss Weight: 1.0
# Activation Function: Tanh()

# %%
best_trial = "best_trial"
labels = [best_trial, best_trial]
filepaths=[os.path.join(path, best_trial) + "/train_stats.npy", os.path.join(path, best_trial) + "/test_stats.npy"]
plot_model_stats(filepaths=filepaths, labels=labels, to_plot=["hes"])
print_model_info(filepath=os.path.join(path, best_trial) + "/model.pth")
# Out:
# Last hes: 9.645624160766602
# Last hes: 9.500669479370117
# --- Model Parameters ---
# PDE Name: Allen-Cahn
# PDE Parameters: [0.0]
# Hidden Units: [50, 50, 50, 50]
# Initial Learning Rate (lr_init): 0.0005433864190414326
# Batch size (batch_size): 2048
# BC Loss Weight: 0.0033884507088243615
# IC Loss Weight: 1.0
# Physics Loss Weight: 0.0016602264079493237
# Distillation Loss Weight: 1.0
# EWC Loss Weight: 1.0
# Activation Function: Tanh()

# %%
best_trial = "best_trial"
labels = [best_trial, best_trial]
filepaths=[os.path.join(path, best_trial) + "/train_stats.npy", os.path.join(path, best_trial) + "/test_stats.npy"]
plot_model_stats(filepaths=filepaths, labels=labels, to_plot=["bc"])
print_model_info(filepath=os.path.join(path, best_trial) + "/model.pth")
# Out:
# Last bc: 0.0010273035150021315
# Last bc: 0.0010102048981934786
# --- Model Parameters ---
# PDE Name: Allen-Cahn
# PDE Parameters: [0.0]
# Hidden Units: [50, 50, 50, 50]
# Initial Learning Rate (lr_init): 0.0005433864190414326
# Batch size (batch_size): 2048
# BC Loss Weight: 0.0033884507088243615
# IC Loss Weight: 1.0
# Physics Loss Weight: 0.0016602264079493237
# Distillation Loss Weight: 1.0
# EWC Loss Weight: 1.0
# Activation Function: Tanh()
