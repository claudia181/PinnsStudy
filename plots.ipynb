# %%
from plot_utils import plot_points, plot_model_stats, print_model_info, plot_loss
import os
from evaluate import evaluate

# %% [markdown]
# # Data

# %%
plot_points('data/train/0/full/random_dom.pth', points_idx = 0, labels_idx = 1)

# %% [markdown]
# # PINN full

# %%
path = "models/AllenCahnSingle0/PINNfull0"

subdirs = []
for entry_name in os.listdir(path):
        full_path = os.path.join(path, entry_name)
        if os.path.isdir(full_path):
                subdirs.append(entry_name)

selection = [
        "trial0",
        "trial1",
        "trial2",
        "trial3",
        "trial4",
        "trial5",
        "trial6",
        "trial7",
        "trial8",
        "trial9"
        ]

labels = [trial for trial in os.listdir(path) if trial in selection]
filepaths=[os.path.join(path, trial) + "/train_stats.npy" for trial in subdirs if trial in selection]

plot_model_stats(filepaths=filepaths, labels=labels, to_plot=["train"])

filepaths=[os.path.join(path, trial) + "/test_stats.npy" for trial in subdirs if trial in selection]

plot_model_stats(filepaths=filepaths, labels=labels, to_plot=["test"])

# %%
best_trial = "trial5"
labels = [best_trial, best_trial]
filepaths=[os.path.join(path, best_trial) + "/train_stats.npy", os.path.join(path, best_trial) + "/test_stats.npy"]
plot_model_stats(filepaths=filepaths, labels=labels, to_plot=["train", "test"])
print_model_info(filepath=os.path.join(path, best_trial) + "/model.pth")
# Out:
# --- Model Parameters ---
# PDE Name: Allen-Cahn
# PDE Parameters: [0.0]
# Hidden Units: [50, 50, 50, 50]
# Initial Learning Rate (lr_init): 7.508569727532212e-05
# Batch size (batch_size): 2048
# BC Loss Weight: 0.07023155682572046
# IC Loss Weight: 1.0
# Physics Loss Weight: 0.001822706204678068
# Distillation Loss Weight: 1.0
# EWC Loss Weight: 1.0
# Activation Function: Tanh()

# %% [markdown]
# # PINN single

# %% [markdown]
# ## Top left

# %%
path = "models/AllenCahnSingle0/PINNtl0"

subdirs = []
for entry_name in os.listdir(path):
        full_path = os.path.join(path, entry_name)
        if os.path.isdir(full_path):
                subdirs.append(entry_name)

selection = [
        "trial0",
        "trial1",
        "trial2",
        "trial3",
        "trial4",
        "trial5",
        "trial6",
        "trial7",
        "trial8",
        "trial9"
        ]

labels = [trial for trial in os.listdir(path) if trial in selection]
filepaths=[os.path.join(path, trial) + "/train_stats.npy" for trial in subdirs if trial in selection]

plot_model_stats(filepaths=filepaths, labels=labels, to_plot=["train"])

filepaths=[os.path.join(path, trial) + "/test_stats.npy" for trial in subdirs if trial in selection]

plot_model_stats(filepaths=filepaths, labels=labels, to_plot=["test"])

# %%
best_trial = "trial0"
labels = [best_trial, best_trial]
filepaths=[os.path.join(path, best_trial) + "/train_stats.npy", os.path.join(path, best_trial) + "/test_stats.npy"]
plot_model_stats(filepaths=filepaths, labels=labels, to_plot=["train", "test"])
print_model_info(filepath=os.path.join(path, best_trial) + "/model.pth")
# Out:
# --- Model Parameters ---
# PDE Name: Allen-Cahn
# PDE Parameters: [0.0]
# Hidden Units: [50, 50, 50, 50]
# Initial Learning Rate (lr_init): 1.9590877642213916e-05
# Batch size (batch_size): 2048
# BC Loss Weight: 0.028225506363173766
# IC Loss Weight: 1.0
# Physics Loss Weight: 0.0011270808146720897
# Distillation Loss Weight: 1.0
# EWC Loss Weight: 1.0
# Activation Function: Tanh()

# %% [markdown]
# ## Top right

# %%
path = "models/AllenCahnSingle0/PINNtr0"

subdirs = []
for entry_name in os.listdir(path):
        full_path = os.path.join(path, entry_name)
        if os.path.isdir(full_path):
                subdirs.append(entry_name)

selection = [
        "trial0",
        "trial1",
        "trial2",
        "trial3",
        "trial4",
        "trial5",
        "trial6",
        "trial7",
        "trial8",
        "trial9"
        ]

labels = [trial for trial in os.listdir(path) if trial in selection]
filepaths=[os.path.join(path, trial) + "/train_stats.npy" for trial in subdirs if trial in selection]

plot_model_stats(filepaths=filepaths, labels=labels, to_plot=["train"])

filepaths=[os.path.join(path, trial) + "/test_stats.npy" for trial in subdirs if trial in selection]

plot_model_stats(filepaths=filepaths, labels=labels, to_plot=["test"])

# %%
best_trial = "trial0"
labels = [best_trial, best_trial]
filepaths=[os.path.join(path, best_trial) + "/train_stats.npy", os.path.join(path, best_trial) + "/test_stats.npy"]
plot_model_stats(filepaths=filepaths, labels=labels, to_plot=["train", "test"])
print_model_info(filepath=os.path.join(path, best_trial) + "/model.pth")
# Out:
# --- Model Parameters ---
# PDE Name: Allen-Cahn
# PDE Parameters: [0.0]
# Hidden Units: [50, 50, 50, 50]
# Initial Learning Rate (lr_init): 1.9590877642213916e-05
# Batch size (batch_size): 2048
# BC Loss Weight: 0.028225506363173766
# IC Loss Weight: 1.0
# Physics Loss Weight: 0.0011270808146720897
# Distillation Loss Weight: 1.0
# EWC Loss Weight: 1.0
# Activation Function: Tanh()

# %% [markdown]
# ## Down right

# %%
path = "models/AllenCahnSingle0/PINNdr0"

subdirs = []
for entry_name in os.listdir(path):
        full_path = os.path.join(path, entry_name)
        if os.path.isdir(full_path):
                subdirs.append(entry_name)

selection = [
        "trial0",
        "trial1",
        "trial2",
        "trial3",
        "trial4",
        "trial5",
        "trial6",
        "trial7",
        "trial8",
        "trial9"
        ]

labels = [trial for trial in os.listdir(path) if trial in selection]
filepaths=[os.path.join(path, trial) + "/train_stats.npy" for trial in subdirs if trial in selection]

plot_model_stats(filepaths=filepaths, labels=labels, to_plot=["train"])

filepaths=[os.path.join(path, trial) + "/test_stats.npy" for trial in subdirs if trial in selection]

plot_model_stats(filepaths=filepaths, labels=labels, to_plot=["test"])

# %%
best_trial = "trial8"
labels = [best_trial, best_trial]
filepaths=[os.path.join(path, best_trial) + "/train_stats.npy", os.path.join(path, best_trial) + "/test_stats.npy"]
plot_model_stats(filepaths=filepaths, labels=labels, to_plot=["train", "test"])
print_model_info(filepath=os.path.join(path, best_trial) + "/model.pth")
# Out:
# --- Model Parameters ---
# PDE Name: Allen-Cahn
# PDE Parameters: [0.0]
# Hidden Units: [50, 50, 50, 50]
# Initial Learning Rate (lr_init): 2.7516890600339487e-05
# Batch size (batch_size): 2048
# BC Loss Weight: 0.07504098441628451
# IC Loss Weight: 1.0
# Physics Loss Weight: 0.001933217632341429
# Distillation Loss Weight: 1.0
# EWC Loss Weight: 1.0
# Activation Function: Tanh()

# %% [markdown]
# ## Down left

# %%
path = "models/AllenCahnSingle0/PINNdl0"

subdirs = []
for entry_name in os.listdir(path):
        full_path = os.path.join(path, entry_name)
        if os.path.isdir(full_path):
                subdirs.append(entry_name)

selection = [
        "trial0",
        "trial1",
        "trial2",
        "trial3",
        "trial4",
        "trial5",
        "trial6",
        "trial7",
        "trial8",
        "trial9"
        ]

labels = [trial for trial in os.listdir(path) if trial in selection]
filepaths=[os.path.join(path, trial) + "/train_stats.npy" for trial in subdirs if trial in selection]

plot_model_stats(filepaths=filepaths, labels=labels, to_plot=["train"])

filepaths=[os.path.join(path, trial) + "/test_stats.npy" for trial in subdirs if trial in selection]

plot_model_stats(filepaths=filepaths, labels=labels, to_plot=["test"])

# %%
best_trial = "trial6"
labels = [best_trial, best_trial]
filepaths=[os.path.join(path, best_trial) + "/train_stats.npy", os.path.join(path, best_trial) + "/test_stats.npy"]
plot_model_stats(filepaths=filepaths, labels=labels, to_plot=["train", "test"])
print_model_info(filepath=os.path.join(path, best_trial) + "/model.pth")
# Out:
# --- Model Parameters ---
# PDE Name: Allen-Cahn
# PDE Parameters: [0.0]
# Hidden Units: [50, 50, 50, 50]
# Initial Learning Rate (lr_init): 1.9667263070800675e-05
# Batch size (batch_size): 2048
# BC Loss Weight: 0.007676867706376913
# IC Loss Weight: 1.0
# Physics Loss Weight: 0.0014570392626754478
# Distillation Loss Weight: 1.0
# EWC Loss Weight: 1.0
# Activation Function: Tanh()

# %% [markdown]
# # PINN forgetting

# %% [markdown]
# ## Step 1: top right

# %%
path = "models/AllenCahnSingle0/PINNtr1"

subdirs = []
for entry_name in os.listdir(path):
        full_path = os.path.join(path, entry_name)
        if os.path.isdir(full_path):
                subdirs.append(entry_name)

selection = [
        "trial0",
        "trial1",
        "trial2",
        "trial3",
        "trial4",
        "trial5",
        "trial6",
        "trial7",
        "trial8",
        "trial9"
        ]

labels = [trial for trial in os.listdir(path) if trial in selection]
filepaths=[os.path.join(path, trial) + "/train_stats.npy" for trial in subdirs if trial in selection]

plot_model_stats(filepaths=filepaths, labels=labels, to_plot=["train"])

filepaths=[os.path.join(path, trial) + "/test_stats.npy" for trial in subdirs if trial in selection]

plot_model_stats(filepaths=filepaths, labels=labels, to_plot=["test"])

# %%
best_trial = "trial7"
labels = [best_trial, best_trial]
filepaths=[os.path.join(path, best_trial) + "/train_stats.npy", os.path.join(path, best_trial) + "/test_stats.npy"]
plot_model_stats(filepaths=filepaths, labels=labels, to_plot=["train", "test"])
print_model_info(filepath=os.path.join(path, best_trial) + "/model.pth")
# Out:
# --- Model Parameters ---
# PDE Name: Allen-Cahn
# PDE Parameters: [0.0]
# Hidden Units: [50, 50, 50, 50]
# Initial Learning Rate (lr_init): 9.389149624562901e-05
# Batch size (batch_size): 2048
# BC Loss Weight: 0.03676883590167885
# IC Loss Weight: 1.0
# Physics Loss Weight: 0.0020482838497444134
# Distillation Loss Weight: 1.0
# EWC Loss Weight: 1.0
# Activation Function: Tanh()

# %% [markdown]
# ## Step 2: down right

# %%
path = "models/AllenCahnSingle0/PINNdr2"

subdirs = []
for entry_name in os.listdir(path):
        full_path = os.path.join(path, entry_name)
        if os.path.isdir(full_path):
                subdirs.append(entry_name)

selection = [
        "trial0",
        "trial1",
        "trial2",
        "trial3",
        "trial4",
        "trial5",
        "trial6",
        "trial7",
        "trial8",
        "trial9"
        ]

labels = [trial for trial in os.listdir(path) if trial in selection]
filepaths=[os.path.join(path, trial) + "/train_stats.npy" for trial in subdirs if trial in selection]

plot_model_stats(filepaths=filepaths, labels=labels, to_plot=["train"])

filepaths=[os.path.join(path, trial) + "/test_stats.npy" for trial in subdirs if trial in selection]

plot_model_stats(filepaths=filepaths, labels=labels, to_plot=["test"])

# %%
best_trial = "trial2"
labels = [best_trial, best_trial]
filepaths=[os.path.join(path, best_trial) + "/train_stats.npy", os.path.join(path, best_trial) + "/test_stats.npy"]
plot_model_stats(filepaths=filepaths, labels=labels, to_plot=["train", "test"])
print_model_info(filepath=os.path.join(path, best_trial) + "/model.pth")
# Out:
# --- Model Parameters ---
# PDE Name: Allen-Cahn
# PDE Parameters: [0.0]
# Hidden Units: [50, 50, 50, 50]
# Initial Learning Rate (lr_init): 9.389149624562901e-05
# Batch size (batch_size): 2048
# BC Loss Weight: 0.03676883590167885
# IC Loss Weight: 1.0
# Physics Loss Weight: 0.0020482838497444134
# Distillation Loss Weight: 1.0
# EWC Loss Weight: 1.0
# Activation Function: Tanh()

# %% [markdown]
# ## Step 3: down left

# %%
path = "models/AllenCahnSingle0/PINNdl3"

subdirs = []
for entry_name in os.listdir(path):
        full_path = os.path.join(path, entry_name)
        if os.path.isdir(full_path):
                subdirs.append(entry_name)

selection = [
        "trial0",
        "trial1",
        "trial2",
        "trial3",
        "trial4",
        "trial5",
        "trial6",
        "trial7",
        "trial8",
        "trial9"
        ]

labels = [trial for trial in os.listdir(path) if trial in selection]
filepaths=[os.path.join(path, trial) + "/train_stats.npy" for trial in subdirs if trial in selection]

plot_model_stats(filepaths=filepaths, labels=labels, to_plot=["train"])

filepaths=[os.path.join(path, trial) + "/test_stats.npy" for trial in subdirs if trial in selection]

plot_model_stats(filepaths=filepaths, labels=labels, to_plot=["test"])

# %%
best_trial = "trial1"
labels = [best_trial, best_trial]
filepaths=[os.path.join(path, best_trial) + "/train_stats.npy", os.path.join(path, best_trial) + "/test_stats.npy"]
plot_model_stats(filepaths=filepaths, labels=labels, to_plot=["train", "test"])
print_model_info(filepath=os.path.join(path, best_trial) + "/model.pth")
# Out:
# --- Model Parameters ---
# PDE Name: Allen-Cahn
# PDE Parameters: [0.0]
# Hidden Units: [50, 50, 50, 50]
# Initial Learning Rate (lr_init): 9.389149624562901e-05
# Batch size (batch_size): 2048
# BC Loss Weight: 0.03676883590167885
# IC Loss Weight: 1.0
# Physics Loss Weight: 0.0020482838497444134
# Distillation Loss Weight: 1.0
# EWC Loss Weight: 1.0
# Activation Function: Tanh()

# %% [markdown]
# # Eval

# %%
model_prefix = "models/AllenCahnSingle0/"
model_suffix = "/model.pth"
data_prefix = "data/val/0/"
data_suffix = "/random_dom.pth"

# %%
model_names = ["PINNtl0", "PINNtr1", "PINNdr2", "PINNdl3"]
data_names = ["top_left", "top_right", "down_right", "down_left"]

model_paths = [model_prefix + f"{model_name}/trial0" + model_suffix for model_name in model_names]
data_paths = [data_prefix + data_name + data_suffix for data_name in data_names]
plot_loss(model_sequence=model_paths, losses=["pde"], data_sequence=data_paths, title="PDE Loss Evolution Domain Partitions")

data_names = ["full"]

data_paths = [data_prefix + data_name + data_suffix for data_name in data_names]
plot_loss(model_sequence=model_paths, losses=["pde"], data_sequence=data_paths, title="PDE Loss Evolution Full Domain")

# %%
model_names = ["PINNtl0", "PINNtr1", "PINNdr2", "PINNdl3"]
data_names = ["top_left", "top_right", "down_right", "down_left"]

model_paths = [model_prefix + f"{model_name}/trial0" + model_suffix for model_name in model_names]
data_paths = [data_prefix + data_name + data_suffix for data_name in data_names]
plot_loss(model_sequence=model_paths, losses=["out"], data_sequence=data_paths, title="OUT Loss Evolution Domain Partitions")

data_names = ["full"]

data_paths = [data_prefix + data_name + data_suffix for data_name in data_names]
plot_loss(model_sequence=model_paths, losses=["out"], data_sequence=data_paths, title="OUT Loss Evolution Full Domain")

# %%
model_names = ["PINNtl0", "PINNtr1", "PINNdr2", "PINNdl3"]
data_names = ["top_left", "top_right", "down_right", "down_left"]

model_paths = [model_prefix + f"{model_name}/trial0" + model_suffix for model_name in model_names]
data_paths = [data_prefix + data_name + data_suffix for data_name in data_names]
plot_loss(model_sequence=model_paths, losses=["der"], data_sequence=data_paths, title="DER Loss Evolution Domain Partitions")

data_names = ["full"]

data_paths = [data_prefix + data_name + data_suffix for data_name in data_names]
plot_loss(model_sequence=model_paths, losses=["der"], data_sequence=data_paths, title="DER Loss Evolution Full Domain")

# %%
model_names = ["PINNtl0", "PINNtr1", "PINNdr2", "PINNdl3"]
data_names = ["top_left", "top_right", "down_right", "down_left"]

model_paths = [model_prefix + f"{model_name}/trial0" + model_suffix for model_name in model_names]
data_paths = [data_prefix + data_name + data_suffix for data_name in data_names]
plot_loss(model_sequence=model_paths, losses=["hes"], data_sequence=data_paths, title="HES Loss Evolution Domain Partitions")

data_names = ["full"]

data_paths = [data_prefix + data_name + data_suffix for data_name in data_names]
plot_loss(model_sequence=model_paths, losses=["hes"], data_sequence=data_paths, title="HES Loss Evolution Full Domain")

# %%
model_name = "PINNdr2"
model_path = model_prefix + f"{model_name}/trial2" + model_suffix
data_path = data_prefix + "top_left" + data_suffix

evaluate(model_path=model_path, data_path=data_path, model_name=model_name)
# Out:
# -------- PINNdr2 --------
# OUT loss: 0.25748297572135925
# DER loss: 1.7792847156524658
# HES loss: 18.90582275390625
# PDE loss: 0.046845339238643646

# %%
model_name = "PINNdl3"
model_path = model_prefix + f"{model_name}/trial1" + model_suffix
data_path = data_prefix + "top_left" + data_suffix

evaluate(model_path=model_path, data_path=data_path, model_name=model_name)
# Out:
# -------- PINNdl3 --------
# OUT loss: 0.2644764482975006
# DER loss: 1.7790623903274536
# HES loss: 18.90468406677246
# PDE loss: 0.050003781914711

# %% [markdown]
# ## Comp

# %%
model_path0 = "models/AllenCahnSingle0/PINN0/trial7/model.pth"
model_path1 = "models/AllenCahnSingle0/PINN1/trial7/model.pth"
model_path2 = "models/AllenCahnSingle0/PINN2/trial3/model.pth"
model_path3 = "models/AllenCahnSingle0/PINN3/trial1/model.pth"
model_pathFull = "models/AllenCahnSingle0/PINNFull/trial0/model.pth"
model_paths = [model_path0, model_path1, model_path2, model_path3, model_pathFull]

data_path0 = "data/train/0/top_left/random_dom.pth"
data_path1 = "data/train/0/top_right/random_dom.pth"
data_path2 = "data/train/0/down_right/random_dom.pth"
data_path3 = "data/train/0/down_left/random_dom.pth"
data_pathFull = "data/train/0/full/random_dom.pth"
data_paths = [data_path0, data_path1, data_path2, data_path3, data_pathFull]

model_names = [f"PINN{i}" for i in range(4)]
model_names.append("PINNFull")

for model_path, data_path, model_name in zip(model_paths, data_paths, model_names):
    evaluate(model_path=model_path, data_path=data_path, model_name=model_name)
# Out:
# -------- PINN0 --------
# OUT loss: 0.18937216699123383
# DER loss: 1.8538897037506104
# HES loss: 18.399391174316406
# PDE loss: 0.022062789648771286
#
# -------- PINN1 --------
# OUT loss: 0.1311144381761551
# DER loss: 0.9297466278076172
# HES loss: 21.147953033447266
# PDE loss: 0.0271176528185606
#
# -------- PINN2 --------
# OUT loss: 0.19951483607292175
# DER loss: 2.276280641555786
# HES loss: 16.718971252441406
# PDE loss: 0.04777142405509949
#
# -------- PINN3 --------
# OUT loss: 0.25131332874298096
# DER loss: 1.7906467914581299
# HES loss: 18.439029693603516
# PDE loss: 0.03537636995315552
#
# -------- PINNFull --------
# OUT loss: 0.2544765770435333
# DER loss: 1.8436521291732788
# HES loss: 18.309537887573242
# PDE loss: 0.04715721309185028

# %%
data_path0 = "data/train/0/top_left/random_dom.pth"
data_path1 = "data/train/0/top_left/random_dom.pth"
data_path2 = "data/train/0/top_right/random_dom.pth"
data_path3 = "data/train/0/down_right/random_dom.pth"
data_pathFull = "data/train/0/full/random_dom.pth"

data_paths = [data_path0, data_path1, data_path2, data_path3, data_pathFull]

for model_path, data_path, model_name in zip(model_paths, data_paths, model_names):
    evaluate(model_path=model_path, data_path=data_path, model_name=model_name)
# Out:
# -------- PINN0 --------
# OUT loss: 0.18937216699123383
# DER loss: 1.8538897037506104
# HES loss: 18.399391174316406
# PDE loss: 0.022062789648771286
#
# -------- PINN1 --------
# OUT loss: 0.26291579008102417
# DER loss: 1.8600341081619263
# HES loss: 18.438880920410156
# PDE loss: 0.05064554512500763
#
# -------- PINN2 --------
# OUT loss: 0.14048469066619873
# DER loss: 0.9297835230827332
# HES loss: 21.15062713623047
# PDE loss: 0.03203471377491951
#
# -------- PINN3 --------
# OUT loss: 0.24044018983840942
# DER loss: 2.2827835083007812
# HES loss: 16.735849380493164
# PDE loss: 0.07037953287363052
#
# -------- PINNFull --------
# OUT loss: 0.2544765770435333
# DER loss: 1.8436521291732788
# HES loss: 18.309537887573242
# PDE loss: 0.04715721309185028

# %%
data_path0 = "data/train/0/full/random_dom.pth"
data_path1 = "data/train/0/full/random_dom.pth"
data_path2 = "data/train/0/full/random_dom.pth"
data_path3 = "data/train/0/full/random_dom.pth"
data_pathFull = "data/train/0/full/random_dom.pth"
data_paths = [data_path0, data_path1, data_path2, data_path3, data_pathFull]

for model_path, data_path, model_name in zip(model_paths, data_paths, model_names):
    evaluate(model_path=model_path, data_path=data_path, model_name=model_name)
# Out:
# -------- PINN0 --------
# OUT loss: 0.2619065046310425
# DER loss: 1.8443260192871094
# HES loss: 18.312074661254883
# PDE loss: 0.05211994796991348
#
# -------- PINN1 --------
# OUT loss: 0.25433534383773804
# DER loss: 1.8434081077575684
# HES loss: 18.310935974121094
# PDE loss: 0.046516019850969315
#
# -------- PINN2 --------
# OUT loss: 0.255161315202713
# DER loss: 1.8433715105056763
# HES loss: 18.312519073486328
# PDE loss: 0.0468321293592453
#
# -------- PINN3 --------
# OUT loss: 0.2548529803752899
# DER loss: 1.843615174293518
# HES loss: 18.30940055847168
# PDE loss: 0.047755852341651917
#
# -------- PINNFull --------
# OUT loss: 0.2544765770435333
# DER loss: 1.8436521291732788
# HES loss: 18.309537887573242
# PDE loss: 0.04715721309185028
