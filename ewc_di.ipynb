# %%
from plot_utils import plot_points, plot_model_stats, print_model_info, plot_loss
import os
from evaluate import evaluate

# %% [markdown]
# # PINN single

# %%
best_trials0 = []

# %% [markdown]
# ## Top left

# %%
path = "models/AllenCahnSingle0/PINNtl0"

subdirs = []
for entry_name in os.listdir(path):
        full_path = os.path.join(path, entry_name)
        if os.path.isdir(full_path):
                subdirs.append(entry_name)

selection = [
        "trial0",
        "trial1",
        "trial2",
        "trial3",
        "trial4",
        "trial5",
        "trial6",
        "trial7",
        "trial8",
        "trial9"
        ]

labels = [trial for trial in os.listdir(path) if trial in selection]
filepaths=[os.path.join(path, trial) + "/train_stats.npy" for trial in subdirs if trial in selection]

plot_model_stats(filepaths=filepaths, labels=labels, to_plot=["train"])

filepaths=[os.path.join(path, trial) + "/test_stats.npy" for trial in subdirs if trial in selection]

plot_model_stats(filepaths=filepaths, labels=labels, to_plot=["test"])

# %%
best_trial = "trial0"
labels = [best_trial, best_trial]
filepaths=[os.path.join(path, best_trial) + "/train_stats.npy", os.path.join(path, best_trial) + "/test_stats.npy"]
plot_model_stats(filepaths=filepaths, labels=labels, to_plot=["train", "test"])
print_model_info(filepath=os.path.join(path, best_trial) + "/model.pth")
# Out:
# --- Model Parameters ---
# PDE Name: Allen-Cahn
# PDE Parameters: [0.0]
# Hidden Units: [50, 50, 50, 50]
# Initial Learning Rate (lr_init): 9.389149624562901e-05
# Batch size (batch_size): 2048
# BC Loss Weight: 0.03676883590167885
# IC Loss Weight: 1.0
# Physics Loss Weight: 0.0020482838497444134
# Distillation Loss Weight: 1.0
# EWC Loss Weight: 1.0
# Activation Function: Tanh()

# %%
best_trials0.append(best_trial)

# %% [markdown]
# # PINN derivative distillation on past data

# %%
best_trials = ["trial0"]
mode = "ewc"

# %% [markdown]
# ## Step 1: top right

# %%
path = f"models/AllenCahnSingle0/{mode}/PINNtr1"

subdirs = []
for entry_name in os.listdir(path):
        full_path = os.path.join(path, entry_name)
        if os.path.isdir(full_path):
                subdirs.append(entry_name)

selection = [
        "trial0",
        "trial1",
        "trial2",
        "trial3",
        "trial4",
        "trial5",
        "trial6",
        "trial7",
        "trial8",
        "trial9"
        ]

labels = [trial for trial in os.listdir(path) if trial in selection]
filepaths=[os.path.join(path, trial) + "/train_stats.npy" for trial in subdirs if trial in selection]

plot_model_stats(filepaths=filepaths, labels=labels, to_plot=["train"])

filepaths=[os.path.join(path, trial) + "/test_stats.npy" for trial in subdirs if trial in selection]

plot_model_stats(filepaths=filepaths, labels=labels, to_plot=["test"])

# %%
best_trial = "trial0"
labels = [best_trial, best_trial]
filepaths=[os.path.join(path, best_trial) + "/train_stats.npy", os.path.join(path, best_trial) + "/test_stats.npy"]
plot_model_stats(filepaths=filepaths, labels=labels, to_plot=["train", "test"])
print_model_info(filepath=os.path.join(path, best_trial) + "/model.pth")
# Out:
# --- Model Parameters ---
# PDE Name: Allen-Cahn
# PDE Parameters: [0.0]
# Hidden Units: [50, 50, 50, 50]
# Initial Learning Rate (lr_init): 4.119316596308762e-05
# Batch size (batch_size): 2048
# BC Loss Weight: 0.002931488990572755
# IC Loss Weight: 1.0
# Physics Loss Weight: 0.006529978817712048
# Distillation Loss Weight: 1.0
# EWC Loss Weight: 0.004273205973446559
# Activation Function: Tanh()

# %%
best_trials.append(best_trial)

# %% [markdown]
# ## Step 2: down right

# %%
path = f"models/AllenCahnSingle0/{mode}/PINNdr2"

subdirs = []
for entry_name in os.listdir(path):
        full_path = os.path.join(path, entry_name)
        if os.path.isdir(full_path):
                subdirs.append(entry_name)

selection = [
        "trial0",
        "trial1",
        "trial2",
        "trial3",
        "trial4",
        "trial5",
        "trial6",
        "trial7",
        "trial8",
        "trial9"
        ]

labels = [trial for trial in os.listdir(path) if trial in selection]
filepaths=[os.path.join(path, trial) + "/train_stats.npy" for trial in subdirs if trial in selection]

plot_model_stats(filepaths=filepaths, labels=labels, to_plot=["train"])

filepaths=[os.path.join(path, trial) + "/test_stats.npy" for trial in subdirs if trial in selection]

plot_model_stats(filepaths=filepaths, labels=labels, to_plot=["test"])

# %%
best_trial = "trial7"
labels = [best_trial, best_trial]
filepaths=[os.path.join(path, best_trial) + "/train_stats.npy", os.path.join(path, best_trial) + "/test_stats.npy"]
plot_model_stats(filepaths=filepaths, labels=labels, to_plot=["train", "test"])
print_model_info(filepath=os.path.join(path, best_trial) + "/model.pth")
# Out:
# --- Model Parameters ---
# PDE Name: Allen-Cahn
# PDE Parameters: [0.0]
# Hidden Units: [50, 50, 50, 50]
# Initial Learning Rate (lr_init): 9.840983889699492e-05
# Batch size (batch_size): 2048
# BC Loss Weight: 0.002294125071275978
# IC Loss Weight: 1.0
# Physics Loss Weight: 0.0016446666636650165
# Distillation Loss Weight: 1.0
# EWC Loss Weight: 0.0003455206888814502
# Activation Function: Tanh()

# %%
best_trials.append(best_trial)

# %% [markdown]
# ## Step 3: down left

# %%
path = f"models/AllenCahnSingle0/{mode}/PINNdl3"

subdirs = []
for entry_name in os.listdir(path):
        full_path = os.path.join(path, entry_name)
        if os.path.isdir(full_path):
                subdirs.append(entry_name)

selection = [
        "trial0",
        "trial1",
        "trial2",
        "trial3",
        "trial4",
        "trial5",
        "trial6",
        "trial7",
        "trial8",
        "trial9"
        ]

labels = [trial for trial in os.listdir(path) if trial in selection]
filepaths=[os.path.join(path, trial) + "/train_stats.npy" for trial in subdirs if trial in selection]

plot_model_stats(filepaths=filepaths, labels=labels, to_plot=["train"])

filepaths=[os.path.join(path, trial) + "/test_stats.npy" for trial in subdirs if trial in selection]

plot_model_stats(filepaths=filepaths, labels=labels, to_plot=["test"])

# %%
best_trial = "trial8"
labels = [best_trial, best_trial]
filepaths=[os.path.join(path, best_trial) + "/train_stats.npy", os.path.join(path, best_trial) + "/test_stats.npy"]
plot_model_stats(filepaths=filepaths, labels=labels, to_plot=["train", "test"])
print_model_info(filepath=os.path.join(path, best_trial) + "/model.pth")
# Out:
# --- Model Parameters ---
# PDE Name: Allen-Cahn
# PDE Parameters: [0.0]
# Hidden Units: [50, 50, 50, 50]
# Initial Learning Rate (lr_init): 6.499518912976564e-05
# Batch size (batch_size): 2048
# BC Loss Weight: 0.004861833240734806
# IC Loss Weight: 1.0
# Physics Loss Weight: 0.00131489303240328
# Distillation Loss Weight: 1.0
# EWC Loss Weight: 0.006445619369198237
# Activation Function: Tanh()

# %%
best_trials.append(best_trial)

# %% [markdown]
# # Eval

# %%
best_trials
# Out:
# ['trial0', 'trial0', 'trial7', 'trial8']

# %%
model_prefix = "models/AllenCahnSingle0/"
model_suffix = "/model.pth"
data_prefix = "data/val/0/"
data_suffix = "/random_dom.pth"

# %%
model_names = ["PINNtl0", f"{mode}/PINNtr1", f"{mode}/PINNdr2", f"{mode}/PINNdl3"]
data_names = ["top_left", "top_right", "down_right", "down_left"]

model_paths = [model_prefix + f"{model_name}/{trial}" + model_suffix for model_name, trial in zip(model_names, best_trials)]
data_paths = [data_prefix + data_name + data_suffix for data_name in data_names]
plot_loss(model_sequence=model_paths, losses=["pde"], data_sequence=data_paths, title="PDE Loss Evolution Domain Partitions")

data_names = ["full"]

data_paths = [data_prefix + data_name + data_suffix for data_name in data_names]
plot_loss(model_sequence=model_paths, losses=["pde"], data_sequence=data_paths, title="PDE Loss Evolution Full Domain")

# %%
model_names = ["PINNtl0", f"{mode}/PINNtr1", f"{mode}/PINNdr2", f"{mode}/PINNdl3"]
data_names = ["top_left", "top_right", "down_right", "down_left"]

model_paths = [model_prefix + f"{model_name}/{trial}" + model_suffix for model_name, trial in zip(model_names, best_trials)]
data_paths = [data_prefix + data_name + data_suffix for data_name in data_names]
plot_loss(model_sequence=model_paths, losses=["out"], data_sequence=data_paths, title="OUT Loss Evolution Domain Partitions")

data_names = ["full"]

data_paths = [data_prefix + data_name + data_suffix for data_name in data_names]
plot_loss(model_sequence=model_paths, losses=["out"], data_sequence=data_paths, title="OUT Loss Evolution Full Domain")

# %%
model_names = ["PINNtl0", f"{mode}/PINNtr1", f"{mode}/PINNdr2", f"{mode}/PINNdl3"]
data_names = ["top_left", "top_right", "down_right", "down_left"]

model_paths = [model_prefix + f"{model_name}/{trial}" + model_suffix for model_name, trial in zip(model_names, best_trials)]
data_paths = [data_prefix + data_name + data_suffix for data_name in data_names]
plot_loss(model_sequence=model_paths, losses=["der"], data_sequence=data_paths, title="DER Loss Evolution Domain Partitions")

data_names = ["full"]

data_paths = [data_prefix + data_name + data_suffix for data_name in data_names]
plot_loss(model_sequence=model_paths, losses=["der"], data_sequence=data_paths, title="DER Loss Evolution Full Domain")

# %%
model_names = ["PINNtl0", f"{mode}/PINNtr1", f"{mode}/PINNdr2", f"{mode}/PINNdl3"]
data_names = ["top_left", "top_right", "down_right", "down_left"]

model_paths = [model_prefix + f"{model_name}/{trial}" + model_suffix for model_name, trial in zip(model_names, best_trials)]
data_paths = [data_prefix + data_name + data_suffix for data_name in data_names]
plot_loss(model_sequence=model_paths, losses=["hes"], data_sequence=data_paths, title="HES Loss Evolution Domain Partitions")

data_names = ["full"]

data_paths = [data_prefix + data_name + data_suffix for data_name in data_names]
plot_loss(model_sequence=model_paths, losses=["hes"], data_sequence=data_paths, title="HES Loss Evolution Full Domain")

# %%
best_trials.append("trial5")

# %%
model_names = ["PINNtl0", f"{mode}/PINNtr1", f"{mode}/PINNdr2", f"{mode}/PINNdl3", "PINNfull0"]
data_name = "full"

model_paths = [model_prefix + f"{model_name}/{trial}" + model_suffix for model_name, trial in zip(model_names, best_trials)]
data_path = data_prefix + data_name + data_suffix

for model_name, model_path in zip(model_names, model_paths):
    evaluate(model_path=model_path, data_path=data_path, model_name=model_name, print_info=True)
# Out:
# -------- PINNtl0 --------
# OUT loss: 0.2545212507247925
# DER loss: 1.8178611993789673
# HES loss: 18.328781127929688
# PDE loss: 0.047798074781894684
#
# -------- ewc/PINNtr1 --------
# OUT loss: 0.26236650347709656
# DER loss: 1.8188743591308594
# HES loss: 18.30849266052246
# PDE loss: 0.05750003084540367
#
# -------- ewc/PINNdr2 --------
# OUT loss: 0.25578010082244873
# DER loss: 1.818817377090454
# HES loss: 18.314062118530273
# PDE loss: 0.05043122172355652
#
# -------- ewc/PINNdl3 --------
# OUT loss: 0.24898573756217957
# DER loss: 1.8200933933258057
# HES loss: 18.294902801513672
# PDE loss: 0.04561525955796242
#
# -------- PINNfull0 --------
# OUT loss: 0.25339627265930176
# DER loss: 1.817930817604065
# HES loss: 18.323158264160156
# PDE loss: 0.04721822962164879

# %%
best_trials
# Out:
# ['trial0', 'trial4', 'trial5', 'trial7', 'trial5']

# %%
best_trials0 = ['trial0', 'trial0', 'trial8', 'trial6']

# %%
model_names0 = ["PINNtl0", "PINNtr0", "PINNdr0", "PINNdl0"]
model_names = ["PINNtl0", f"{mode}/PINNtr1", f"{mode}/PINNdr2", f"{mode}/PINNdl3"]
data_names = ["top_left", "top_right", "down_right", "down_left"]

model_paths0 = [model_prefix + f"{model_name}/{trial}" + model_suffix for model_name, trial in zip(model_names0, best_trials0)]
model_paths = [model_prefix + f"{model_name}/{trial}" + model_suffix for model_name, trial in zip(model_names, best_trials)]
data_path = data_prefix + data_name + data_suffix

for model_name0, model_name, model_path0, model_path in zip(model_names0, model_names, model_paths0, model_paths):
    evaluate(model_path=model_path0, data_path=data_path, model_name=model_name0, print_info=True)
    evaluate(model_path=model_path, data_path=data_path, model_name=model_name, print_info=True)
# Out:
# -------- PINNtl0 --------
# OUT loss: 0.2545212507247925
# DER loss: 1.8178611993789673
# HES loss: 18.328781127929688
# PDE loss: 0.047798074781894684
#
# -------- PINNtl0 --------
# OUT loss: 0.2545212507247925
# DER loss: 1.8178611993789673
# HES loss: 18.328781127929688
# PDE loss: 0.047798074781894684
#
# -------- PINNtr0 --------
# OUT loss: 0.254369854927063
# DER loss: 1.8181462287902832
# HES loss: 18.327594757080078
# PDE loss: 0.04787895455956459
#
# -------- ewc/PINNtr1 --------
# OUT loss: 0.26236650347709656
# DER loss: 1.8188743591308594
# HES loss: 18.30849266052246
# PDE loss: 0.05750003084540367
#
# -------- PINNdr0 --------
# OUT loss: 0.2543727159500122
# DER loss: 1.818206787109375
# HES loss: 18.329296112060547
# PDE loss: 0.047695592045784
#
# -------- ewc/PINNdr2 --------
# OUT loss: 0.25578010082244873
# DER loss: 1.818817377090454
# HES loss: 18.314062118530273
# PDE loss: 0.05043122172355652
#
# -------- PINNdl0 --------
# OUT loss: 0.25452765822410583
# DER loss: 1.8179800510406494
# HES loss: 18.32697296142578
# PDE loss: 0.048058733344078064
#
# -------- ewc/PINNdl3 --------
# OUT loss: 0.24898573756217957
# DER loss: 1.8200933933258057
# HES loss: 18.294902801513672
# PDE loss: 0.04561525955796242
